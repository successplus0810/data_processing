# %%
import json
import pandas as pd
import snowflake.connector as sf
import os
import xlwings as xw
from xlwings.constants import DeleteShiftDirection
import datetime
import math
pd.options.mode.chained_assignment = None
###### Analyst fill
folder_name = '20210106'

###############################################
config_coles = r"config.json"

file_sql_claimpack = r"cd_gap.sql"
file_sql_summ = r"summarizer.sql"
# file_sql_cd_ref = r"cd_ref.sql"
file_sql_cd_check_again = r"cd_check_again.sql"
file_sql_ven_stop_trading = r"check_ven_stop_trading.sql"
# file_sql_cd_check_prgx = r"cd_check_prgx.sql"

path_check_list = fr"D:\\python\\cd_gap_cl\\national\\{folder_name}\\checklist.xlsx"
path_check_list_promo = fr"D:\\python\\cd_gap_cl\\national\\{folder_name}\\check_list_promo.xlsx"
path_check_list_test = fr"D:\\python\\cd_gap_cl\\national\\{folder_name}\\checklist_1.xlsx"

path_export = fr"D:\\python\\cd_gap_cl\\national\\{folder_name}\\"
path_excel = r"CL_SCAN_Vendorname_Analyst_Date.xlsx"
# path_dna = r"DNA.xlsx"

current_dir = os.getcwd()

def set_up(config):
    """Set up connection to SnowFlake"""
    config = json.loads(open(config).read())
    account = config['snowflake']['account']
    user = config['snowflake']['user']
    warehouse = config['snowflake']['warehouse']
    role = config['snowflake']['role']
    database = config['snowflake']['database']
    schema = config['snowflake']['schema']
    password = config['snowflake']['password']
    auth = config['snowflake']['authenticator']

    conn = sf.connect(user=user, password=password, account=account, authenticator=auth,
                      warehouse=warehouse, role=role, database=database, schema=schema)

    cursor = conn.cursor()
    return cursor
def connect_sql(cursor,file_sql,item_code=0,var_1=0,var_2=0,var_3=0,var_4=0,var_5=0,var_6 =0):
    try:
        # cursor.execute((open(file_sql).read()))
        cursor.execute(open(file_sql).read().format(item_code,var_1,var_2,var_3,var_4,var_5 ,var_6))
        all_rows = cursor.fetchall()
        field_names = [i[0] for i in cursor.description]
    finally:
        pass
        # conn.close()
    df = pd.DataFrame(all_rows)
    try:
        df.columns = field_names
    except ValueError:
        return pd.DataFrame([])
    return df

def convert_to_input_sql(num_list):
    num_list_final = ''
    # print('SUPP LIST',supp_num_list)
    for num_list in num_list:
        num_list_final = num_list_final + "'" + str(num_list) + "',"
    return num_list_final[:-1]

def convert_to_input_function(num_list):
    num_list_final = ''
    # print('SUPP LIST',supp_num_list)
    for num_list in num_list:
        num_list_final = num_list_final + str(num_list) + ','
    return num_list_final[:-1]

def get_info(df_splited):
    supp_num_list = list(df_splited['VENDOR_NUMBER'].drop_duplicates())
    item_list = list(df_splited['ITEMID'].drop_duplicates())

    supp_num_list_final = convert_to_input_sql(num_list = supp_num_list)
    item_list_final = convert_to_input_sql(num_list = item_list)
    item_input_function = convert_to_input_function(num_list = item_list)
    return supp_num_list_final,item_list_final,item_input_function

def writer_excel(data,remove,number_sheet,path_export_final):
    # data = list_data, remove = list_remove,number_sheet= str(index_promo)+'_'+str(gst),path_export_final=path_export_final
    #select sheet
    sheet_df_mapping = {number_sheet: data}
    sheet_df_remove  = {number_sheet: remove}
    # Open Excel in background
    with xw.App(visible=False) as app:
        wb = app.books.open(path_export_final)
        # List of current worksheet names
        current_sheets = [sheet.name for sheet in wb.sheets]
        # Iterate over sheet/df mapping
        # If sheet already exist, overwrite current cotent. Else, add new sheet
        for sheet_name in sheet_df_mapping.keys():
            if sheet_name in current_sheets:
                for df_data in data :
                    wb.sheets(sheet_name).range(df_data['cell_export']).options(index=False,header=False).value = df_data['df']
            else:
                'Name of sheet cannot be found in Excel file, please check again'
        for sheet_name in sheet_df_remove.keys():
            if sheet_name in current_sheets:
                for df_remove in remove :
                    # wb.sheets(sheet_name).range(df_cell['cell_export']).options(index=False,header=False).value = df_cell['df']
                    length_start = df_remove['length_start'] + df_remove['count_df']
                    range_length_to_remove = str(length_start)+':'+ str(df_remove['length_end'])
                    wb.sheets(sheet_name).range(range_length_to_remove).api.Delete(DeleteShiftDirection.xlShiftUp)
            else:
                'Name of sheet cannot be found in Excel file, please check again'
        wb.save(path_export_final)
    return None

def fill_summary_sheet(supp_desc,summary_index_list,path_export_final):
    print('Start fill summary sheet')
    with xw.App(visible=False) as app:
        wb_from = app.books.open(path_export_final)
        summary_index = 1
        for index in summary_index_list:
            wb_from.sheets['Supplier Summary'].range('B'+str(summary_index+7)).value = index
            wb_from.sheets['Supplier Summary'].range('D'+str(summary_index+7)).value = supp_desc
            summary_index += 1
            wb_from.sheets['Supplier Summary'].range('B'+str(summary_index+7)+':N'+str(summary_index+7)).clear_contents()
            summary_index += 1
        length_start = summary_index + 7
        range_length_to_remove = str(length_start -1)+':'+ str(38)
        wb_from.sheets('Supplier Summary').range(range_length_to_remove).api.Delete(DeleteShiftDirection.xlShiftUp)         
        wb_from.save(path_export_final)
    return 'Done fill summary sheet' 

def create_worksheet(index_promo,path_export_final):
    # Open Excel in background
    with xw.App(visible=False) as app:
        if index_promo == '1':
            wb_from = app.books.open(path_excel)
        else :
            wb_from = app.books.open(path_export_final)
        ws_from = wb_from.sheets['template']
        ws_from.copy(before=ws_from, name=index_promo)
        wb_from.save(path_export_final)
    return 'Done create worksheet'     

def remove_sheet_change_xlsb(sheet_name,path_export_final,path_export_final_xlsb):
    print('Start delete sheet & change to xlsb')
    with xw.App(visible=False) as app:
        wb = app.books.open(path_export_final)                
        wb.sheets[sheet_name].delete()
        wb.save(path_export_final_xlsb)
    try:
        os.remove(path_export_final)
    except Exception as e:
        print(e)
    return print('Done delete sheet & change to xlsb')

# item_code=0,var_1=0,var_2=0,var_3=0,var_4=0

def df_sales_data(cursor , file_sql , item_list_dict_gsted,start_date,end_date):
    list_data = []
    list_remove = []
    i = 0
    for key,value in item_list_dict_gsted.items():
        item,brand,uomm = key
        promo_price, scan_rate = value
        uomm = int(uomm)
        df_each_item = connect_sql(cursor = cursor,file_sql = file_sql ,item_code = scan_rate,var_1 =item , var_2 = start_date,var_3=end_date,var_4=brand,var_5=uomm,var_6 =promo_price)
        if i == 0:
            df_merge = df_each_item
        else :
            df_merge = pd.concat([df_merge, df_each_item], ignore_index=True)
        i+=1
    df_merge['ELI_CLAIM'] = df_merge.ITEMQUANTITY_PROMO * df_merge.SCAN_RATE
    dict_data = {'df':df_merge,'cell_export':'B606'}
    dict_remove = {'count_df':len(df_merge),'length_start':606,'length_end':20606}
    list_data.append(dict_data)
    list_remove.append(dict_remove)
    return df_merge,list_data,list_remove

def product_state_summary(df_sales):
    print('Start product_state_summary')
    list_data = []
    list_remove = []
    # df: df_sales
    # Find distict item_code and state
    # writer_excel(df,cell_export,length_start,count_df,length_end,number_sheet,path_export_final)
    df_temp =df_sales.drop_duplicates(['ITEMIDSKU','ITEMNAME','BRANDID','UOM_QTY','STATE'])[['ITEMIDSKU','ITEMNAME','BRANDID','UOM_QTY','STATE']]
    df_temp.insert(2,"BLANK",'')
    # Calculate number of rows
    number_rows_state = len(df_temp)
    dict_data_sku = {'df':df_temp,'cell_export':'B111'}
    dict_remove = {'count_df':number_rows_state,'length_start':111,'length_end':601}
    list_data.append(dict_data_sku)
    list_remove.append(dict_remove)
    print('Done product_state_summary')
    return list_data,list_remove

def product_summary(df_sales):
    print('Start product_summary')
    list_data = []
    list_remove = []
    df_product =df_sales.drop_duplicates(['ITEMIDSKU','ITEMNAME','BRANDID','UOM_QTY'])[['ITEMIDSKU','ITEMNAME','BRANDID','UOM_QTY']]
    df_product.insert(2,"BLANK",'')
    number_rows_sales = len(df_product)
    # writer_excel(df = df_product,path_export_final = path_export_final, cell_export = 'B20',number_sheet = number_sheet,length_start=20 , count_df=number_rows_sales, length_end=116)
    dict_data = {'df':df_product,'cell_export':'B8'}
    dict_remove = {'count_df':number_rows_sales,'length_start':8,'length_end':104}
    list_data.append(dict_data)
    list_remove.append(dict_remove)
    print('Done product_summary')
    return list_data , list_remove

# %%
    cursor = set_up(config = config_coles)
    df_raw = connect_sql(cursor = cursor,file_sql = file_sql_claimpack)
    df_unique_supp = df_raw[['VENDOR_NUMBER','STARTDATE','ENDDATE','CLASSIFY_TYPE','CLASSIFY_CLAIM']].drop_duplicates().values.tolist()
    # Read vendor stop trading
    df_ven_stop_trading = connect_sql(cursor = cursor,file_sql = file_sql_ven_stop_trading)
    list_ven_stop_trading = df_ven_stop_trading['VENDOR_NUM'].drop_duplicates().values.tolist()
    # Create dictionary with supp_num key and list of promo_ids
    # print(df_unique_supp)
    # return 0
    dict_sup_pro = {}
    i=0
    for list_sup in df_unique_supp:
        if i == 0:
            dict_sup_pro[list_sup[0]] = [[list_sup[1]] + [list_sup[2]] +[list_sup[3]]+[list_sup[4]]]
        else:
            if list_sup[0] in dict_sup_pro.keys():
                dict_sup_pro[list_sup[0]].append([list_sup[1]] + [list_sup[2]] +[list_sup[3]]+[list_sup[4]])
                # dict_sup_pro[list_sup[0]].append(list_sup[2])
            else:
                dict_sup_pro[list_sup[0]] = [[list_sup[1]] + [list_sup[2]] +[list_sup[3]]+[list_sup[4]]]
        i+=1
    print('--------------------')
    # return 0
    j = 0
    for supp_num,list_date in dict_sup_pro.items():
        supp_num_convert = convert_to_input_sql(num_list=[supp_num])
        # To classify Check_column
        for date in list_date:
            df_splited = df_raw[(df_raw['VENDOR_NUMBER'] == supp_num) & (df_raw['STARTDATE'] == date[0])& (df_raw['ENDDATE'] == date[1])& (df_raw['CLASSIFY_TYPE'] == date[2]) & (df_raw['CLASSIFY_CLAIM'] == date[3])]   
            print(df_splited)
            if str(supp_num_convert) in list_ven_stop_trading:
                df_splited['CHECK_COLUMN'] = 'VENDOR STOP TRADING'
            elif df_splited['CLASSIFY_TYPE'].unique()[0] == 'CLAIM':
                df_splited['CHECK_COLUMN'] = 'CLAIM'
            elif df_splited['SUM_AMT_GAP'].unique()[0] < 100 :
                df_splited['CHECK_COLUMN'] = 'ELI_EXCLUDE < 100'
            else:
                if df_splited[['ITEMID','REBATE_ENTITLEMENT_NUM']].drop_duplicates().count()[0] == df_splited['ITEMID'].drop_duplicates().count():
                    startgap = df_splited['STARTDATE'].unique()[0]
                    endgap = df_splited['ENDDATE'].unique()[0]
                    classify_claim = df_splited['CLASSIFY_CLAIM'].unique()[0]
                    check_brandid  = df_splited[['BRANDID']].drop_duplicates().values.tolist()
                    check_brandid_final = []
                    for brandid in check_brandid:
                        check_brandid_final.append(brandid[0])
                    list_brandid = ",".join(check_brandid_final)
                    list_brandid = str(list_brandid)
                    df_splited['CHECK_BRANDID'] =  list_brandid
                    df_splited['COUNT_BRANDID']  = len(check_brandid_final)  
                    itemlist = df_splited['ITEMID'].drop_duplicates().values.tolist()
                    itemlist_convert = convert_to_input_function(itemlist)
                    uom_filter = df_splited['MULTIPLIER_NUM'].drop_duplicates().values.tolist()
                    uom_convert = convert_to_input_function(uom_filter)
                    brand_convert = convert_to_input_function(check_brandid_final)
                    check_cd = connect_sql(cursor = cursor,file_sql = file_sql_cd_check_again,item_code=itemlist_convert, var_1 =startgap,var_2 =endgap, var_3 = brand_convert,var_4 = uom_convert, var_5 = classify_claim)
                    if check_cd['CHECK_GAP'].unique()[0] == None:
                        df_splited['CHECK_COLUMN'] = 'TO QA'
                        df_splited['FINALSTARTGAP'] = df_splited['STARTDATE'] 
                        df_splited['FINALENDGAP'] = df_splited['ENDDATE'] 
                    else :
                        if check_cd['CHECK_GAP'].unique()[0] == 'NOGAP':
                            # df_splited['CHECK_COLUMN'] = 'PAID IN CD, CHECK CD AGAIN'
                            item_list =  df_splited[['ITEMID','BRANDID','MULTIPLIER_NUM','CLASSIFY_TYPE','CLASSIFY_CLAIM']].drop_duplicates().values.tolist()
                            i = 0
                            for item in item_list:
                                df_splited_2 = df_splited[(df_splited['ITEMID'] == item[0]) & (df_splited['BRANDID'] == item[1]) & (df_splited['MULTIPLIER_NUM'] == item[2])]
                                check_cd_2 = connect_sql(cursor = cursor,file_sql = file_sql_cd_check_again,item_code=item[0], var_1 =startgap,var_2 =endgap, var_3 = item[1],var_4 = str(item[2]), var_5 = classify_claim)
                                if check_cd_2['CHECK_GAP'].unique()[0] == None:
                                    df_splited_2['CHECK_COLUMN'] = 'TO QA'
                                    df_splited_2['FINALSTARTGAP'] = df_splited['STARTDATE'] 
                                    df_splited_2['FINALENDGAP'] = df_splited['ENDDATE']
                                else:
                                    if check_cd_2['CHECK_GAP'].unique()[0] == 'NOGAP':
                                        df_splited_2['CHECK_COLUMN'] = 'PAID IN CD'
                                    else :
                                        df_splited_2['FINALSTARTGAP'] = check_cd_2['NEWSTARTGAP'].unique()[0]
                                        df_splited_2['FINALENDGAP'] = check_cd_2['NEWENDGAP'].unique()[0]
                                        df_splited_2['CHECK_COLUMN'] = 'PAID PARTITIALY IN CD, CHECK NEWGAP WITH NEWSTARTDATE AND NEWENDDATE'
                                if i  == 0:
                                    df_splited_part = df_splited_2
                                else:
                                    df_splited_part = pd.concat([df_splited_part, df_splited_2], ignore_index=True)
                                i+= 1
                            df_splited = df_splited_part
                        else:
                            df_splited['FINALSTARTGAP'] = check_cd['NEWSTARTGAP'].unique()[0]
                            df_splited['FINALENDGAP'] = check_cd['NEWENDGAP'].unique()[0]
                            df_splited['CHECK_COLUMN'] = 'PAID PARTITIALY IN CD, CHECK NEWGAP WITH NEWSTARTDATE AND NEWENDDATE'
                else:
                    df_splited['CHECK_COLUMN'] = 'CHECK AGAIN'
            if j  == 0:
                    df_raw_check = df_splited
            else:
                    df_raw_check = pd.concat([df_raw_check, df_splited], ignore_index=True)
            j+=1
    #Export checklist
    df_raw_check.to_excel(path_check_list,index=False)
    # return 0
    ###############################################################
    error_list =[]
    time_start = datetime.datetime.now()
    # Filter df_splited with condition , keep TO QA and PRGX
    df_raw_filter = df_raw_check[(df_raw_check['CHECK_COLUMN'] == 'TO QA') | (df_raw_check['CHECK_COLUMN'] == 'PAID PARTITIALY IN CD, CHECK NEWGAP WITH NEWSTARTDATE AND NEWENDDATE')] 
    df_unique_supp_filter = df_raw_filter[['VENDOR_NUMBER','FINALSTARTGAP','FINALENDGAP','CLASSIFY_AMOUNT','CHECK_BRANDID','COUNT_BRANDID']].drop_duplicates().values.tolist()
    # Create dictionary with supp_num key and list of promo_ids after filter conditions, keep check again and to QA
    dict_sup_pro_filter = {}
    j=0

    #Get vendor_number + value(lessthan20k) to key of dictionary
    for list_sup in df_unique_supp_filter:
        if j == 0:
            dict_sup_pro_filter[list_sup[0]+list_sup[3]] = [list_sup]
        else:
            if list_sup[0]+list_sup[3] in dict_sup_pro_filter.keys():
                dict_sup_pro_filter[list_sup[0]+list_sup[3]].append(list_sup)
            else:
                dict_sup_pro_filter[list_sup[0]+list_sup[3]]  = [list_sup]
        j+=1

    #Split 2 brandid to each brandid/sheet, keep 3brandid -> LL
    for key,value_list in dict_sup_pro_filter.items():
        list_split = []
        for value in value_list:
            if value[5] == 2:
                split_all = value[4].split(',')
                for split in split_all:
                    list_split.append([value[0]]+[value[1]]+[value[2]]+[value[3]]+[split]+[value[5]])
            else:
                list_split.append(value)
        dict_sup_pro_filter[key] = list_split
    print(dict_sup_pro_filter)
# Out:
# Initiating login request with your identity provider. A browser window should have opened for you to complete the login. If you can't see it, check existing browser windows, or your OS settings. Press CTRL+C to abort and try again...
# --------------------
#   CLASSIFY_CLAIM CLASSIFY_STATE VENDOR_NUMBER      VENDOR_NAME BRANDID  \
# 0            PRO       national         47651  DIAGEO AUST LTD      VC
#
#     ITEMID                                           ITEMNAME MULTIPLIER_NUM  \
# 0  3641293  KETEL ONE BOTANICAL SPRITZ GRAPEFRUIT & ROSE 7...           1.00
#
#   REBATE_ENTITLEMENT_NUM   STARTDATE  ... PROMO_PRICE_SUGGEST  \
# 0                   2.76  2021-01-28  ...               36.36
#
#   PRICE_ACTUAL_LESS_THAN_PROMO_EXC PROMO_QTY  PROMO_AMT  SUM_AMT_GAP  \
# 0                            32.18     113.0     311.88       311.88
#
#   ITEMGROUP CATEGORY_ID  PAF_LINK_SUGGEST EMAIL_SUGGEST CLASSIFY_AMOUNT
# 0   Spirits        VCS1              None          None    _LESSTHAN20K
#
# [1 rows x 31 columns]
#   CLASSIFY_CLAIM CLASSIFY_STATE VENDOR_NUMBER      VENDOR_NAME BRANDID  \
# 1            PRO       national         47651  DIAGEO AUST LTD      VC
# 2            PRO       national         47651  DIAGEO AUST LTD      VC
#
#     ITEMID                      ITEMNAME MULTIPLIER_NUM  \
# 1  3641373   BELSAZAR DRY VERMOUTH 750ML           1.00
# 2  3641395  BELSAZAR ROSE VERMOUTH 750ML           1.00
#
#   REBATE_ENTITLEMENT_NUM   STARTDATE  ... PROMO_PRICE_SUGGEST  \
# 1                   2.70  2021-02-03  ...               22.73
# 2                   2.68  2021-02-03  ...               22.73
#
#   PRICE_ACTUAL_LESS_THAN_PROMO_EXC PROMO_QTY  PROMO_AMT  SUM_AMT_GAP  \
# 1                            22.60     249.0     672.30      1256.54
# 2                            22.73     218.0     584.24      1256.54
#
#   ITEMGROUP CATEGORY_ID  PAF_LINK_SUGGEST EMAIL_SUGGEST CLASSIFY_AMOUNT
# 1   Spirits        VCS1              None          None    _LESSTHAN20K
# 2   Spirits        VCS1              None          None    _LESSTHAN20K
#
# [2 rows x 31 columns]
#   CLASSIFY_CLAIM CLASSIFY_STATE VENDOR_NUMBER      VENDOR_NAME BRANDID  \
# 3            PRO       national         47651  DIAGEO AUST LTD      1C
# 4            PRO       national         47651  DIAGEO AUST LTD      LL
# 6            PRO       national         47651  DIAGEO AUST LTD      1C
# 7            PRO       national         47651  DIAGEO AUST LTD      LL
#
#     ITEMID                              ITEMNAME MULTIPLIER_NUM  \
# 3  1979710   BUNDABERG MDC SMALL BATCH RUM 700ML           1.00
# 4  1979710   BUNDABERG MDC SMALL BATCH RUM 700ML           1.00
# 6  3466819  DIMPLE 12YO BLENDED SCOTCH WHISKY 1L           1.00
# 7  3628127  COPPER DOG BLENDED MALT WHISKY 700ML           1.00
#
#   REBATE_ENTITLEMENT_NUM   STARTDATE  ... PROMO_PRICE_SUGGEST  \
# 3                   6.62  2021-03-10  ...               50.00
# 4                   6.62  2021-03-10  ...               50.91
# 6                   3.31  2021-03-10  ...               59.09
# 7                   3.77  2021-03-10  ...               47.27
#
#   PRICE_ACTUAL_LESS_THAN_PROMO_EXC PROMO_QTY  PROMO_AMT  SUM_AMT_GAP  \
# 3                            45.17     341.0    2257.42     56644.90
# 4                            50.81    5710.0   37800.20     56644.90
# 6                            59.09    1821.0    6027.51     56644.90
# 7                            47.08    2801.0   10559.77     56644.90
#
#   ITEMGROUP CATEGORY_ID                                   PAF_LINK_SUGGEST  \
# 3   Spirits        1CS1  Z:\RA\PAF\LL Monthly\21112020-28022021-new\LL_...
# 4   Spirits        LLS1  Z:\RA\PAF\LL Monthly\21112020-28022021-new\LL_...
# 6   Spirits        1CS1  Z:\RA\PAF\LL Monthly\21112020-28022021-new\LL_...
# 7   Spirits        LLS1  Z:\RA\PAF\LL Monthly\21112020-28022021-new\LL_...
#
#                                        EMAIL_SUGGEST CLASSIFY_AMOUNT
# 3  Z:\RA\PAF\LL Monthly\21112020-28022021-new\LL_...
# 4  Z:\RA\PAF\LL Monthly\21112020-28022021-new\LL_...
# 6  Z:\RA\PAF\LL Monthly\21112020-28022021-new\LL_...
# 7  Z:\RA\PAF\LL Monthly\21112020-28022021-new\LL_...
#
# [4 rows x 31 columns]
#   CLASSIFY_CLAIM CLASSIFY_STATE VENDOR_NUMBER      VENDOR_NAME BRANDID  \
# 5            PRO       national         47651  DIAGEO AUST LTD      1C
# 8            PRO       national         47651  DIAGEO AUST LTD      LL
#
#     ITEMID                   ITEMNAME MULTIPLIER_NUM REBATE_ENTITLEMENT_NUM  \
# 5  3260777    TANQUERAY SEVILLA 700ML           1.00                   None
# 8  7424490  BUNDABERG RED RUM 1 LITRE           1.00                   None
#
#     STARTDATE  ... PROMO_PRICE_SUGGEST PRICE_ACTUAL_LESS_THAN_PROMO_EXC  \
# 5  2021-03-10  ...               51.82                            51.67
# 8  2021-03-10  ...               56.36                            53.10
#
#   PROMO_QTY  PROMO_AMT  SUM_AMT_GAP ITEMGROUP CATEGORY_ID  \
# 5    1063.0    5591.38      5719.18   Spirits        1CS1
# 8     639.0     127.80      5719.18   Spirits        LLS1
#
#                                     PAF_LINK_SUGGEST  \
# 5  Z:\RA\PAF\LL Monthly\28022021-01052021\PAF\Dia...
# 8                                               None
#
#                                        EMAIL_SUGGEST CLASSIFY_AMOUNT
# 5  Z:\RA\PAF\LL Monthly\28022021-01052021\Email\f...    _LESSTHAN20K
# 8                                               None    _LESSTHAN20K
#
# [2 rows x 31 columns]
#   CLASSIFY_CLAIM CLASSIFY_STATE VENDOR_NUMBER      VENDOR_NAME BRANDID  \
# 9            PRO       national         47651  DIAGEO AUST LTD      VC
#
#    ITEMID                                           ITEMNAME MULTIPLIER_NUM  \
# 9  926379  JOHNNIE WALKER BLACK LABEL 12YO SCOTCH WHISKY ...           1.00
#
#   REBATE_ENTITLEMENT_NUM   STARTDATE  ... PROMO_PRICE_SUGGEST  \
# 9                   None  2021-03-17  ...                60.0
#
#   PRICE_ACTUAL_LESS_THAN_PROMO_EXC PROMO_QTY  PROMO_AMT  SUM_AMT_GAP  \
# 9                            60.00      22.0     137.94       137.94
#
#   ITEMGROUP CATEGORY_ID                                   PAF_LINK_SUGGEST  \
# 9   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
#
#                                        EMAIL_SUGGEST CLASSIFY_AMOUNT
# 9  https://myprofectus.sharepoint.com/:f:/r/sites...    _LESSTHAN20K
#
# [1 rows x 31 columns]
#    CLASSIFY_CLAIM CLASSIFY_STATE VENDOR_NUMBER      VENDOR_NAME BRANDID  \
# 10            PRO       national         47651  DIAGEO AUST LTD      1C
# 11            PRO       national         47651  DIAGEO AUST LTD      1C
# 12            PRO       national         47651  DIAGEO AUST LTD      1C
# 13            PRO       national         47651  DIAGEO AUST LTD      1C
# 14            PRO       national         47651  DIAGEO AUST LTD      1C
# 15            PRO       national         47651  DIAGEO AUST LTD      1C
# 16            PRO       national         47651  DIAGEO AUST LTD      1C
# 17            PRO       national         47651  DIAGEO AUST LTD      1C
#
#      ITEMID                                         ITEMNAME MULTIPLIER_NUM  \
# 10  3189719                                  JINZU GIN 700ML           1.00
# 11  3189719                                  JINZU GIN 700ML           1.00
# 12  3243483  SINGLETON OF DUFFTOWN 12YO SCOTCH WHISKEY 700ML           1.00
# 13    32872                              TANQUERAY GIN 700ML           1.00
# 14    32872                              TANQUERAY GIN 700ML           1.00
# 15    32872                              TANQUERAY GIN 700ML           1.00
# 16   569651                                GORDONS GIN 700ML           1.00
# 17   569651                                GORDONS GIN 700ML           1.00
#
#    REBATE_ENTITLEMENT_NUM   STARTDATE  ... PROMO_PRICE_SUGGEST  \
# 10                   None  2021-04-07  ...               50.91
# 11                   None  2021-04-07  ...               50.91
# 12                   None  2021-04-07  ...               54.55
# 13                   None  2021-04-07  ...               41.82
# 14                   None  2021-04-07  ...               41.82
# 15                   None  2021-04-07  ...               41.82
# 16                   None  2021-04-07  ...               34.55
# 17                   None  2021-04-07  ...               34.55
#
#    PRICE_ACTUAL_LESS_THAN_PROMO_EXC PROMO_QTY  PROMO_AMT  SUM_AMT_GAP  \
# 10                            48.38      17.0      77.86     11193.09
# 11                            48.38      34.0     115.94     11193.09
# 12                            54.55       4.0      20.36     11193.09
# 13                            41.00     139.0     314.14     11193.09
# 14                            41.00     139.0     175.14     11193.09
# 15                            41.00     139.0      69.50     11193.09
# 16                            34.54    5083.0    6658.73     11193.09
# 17                            34.54   10166.0    3761.42     11193.09
#
#    ITEMGROUP CATEGORY_ID                                   PAF_LINK_SUGGEST  \
# 10   Spirits        1CS1  Z:\RA\PAF\LL Monthly\01052021-01062021\PAF\Dia...
# 11   Spirits        1CS1                                               None
# 12   Spirits        1CS1                                               None
# 13   Spirits        1CS1  Z:\RA\PAF\LL Monthly\21112020-28022021-new\LL_...
# 14   Spirits        1CS1                                               None
# 15   Spirits        1CS1  Z:\RA\PAF\LL Monthly\21112020-28022021-new\LL_...
# 16   Spirits        1CS1                                               None
# 17   Spirits        1CS1                                               None
#
#                                         EMAIL_SUGGEST CLASSIFY_AMOUNT
# 10  Z:\RA\PAF\LL Monthly\01052021-01062021\Email\r...    _LESSTHAN20K
# 11                                               None    _LESSTHAN20K
# 12                                               None    _LESSTHAN20K
# 13  Z:\RA\PAF\LL Monthly\21112020-28022021-new\LL_...    _LESSTHAN20K
# 14                                               None    _LESSTHAN20K
# 15  Z:\RA\PAF\LL Monthly\21112020-28022021-new\LL_...    _LESSTHAN20K
# 16                                               None    _LESSTHAN20K
# 17                                               None    _LESSTHAN20K
#
# [8 rows x 31 columns]
#    CLASSIFY_CLAIM CLASSIFY_STATE VENDOR_NUMBER      VENDOR_NAME BRANDID  \
# 18            PRO       national         47651  DIAGEO AUST LTD      LL
# 19            PRO       national         47651  DIAGEO AUST LTD      LL
#
#      ITEMID                  ITEMNAME MULTIPLIER_NUM REBATE_ENTITLEMENT_NUM  \
# 18  6593222  BUNDABERG UP RUM 1 LITRE           1.00                   None
# 19  6593222  BUNDABERG UP RUM 1 LITRE           1.00                   None
#
#      STARTDATE  ... PROMO_PRICE_SUGGEST PRICE_ACTUAL_LESS_THAN_PROMO_EXC  \
# 18  2021-04-19  ...               49.09                            49.09
# 19  2021-04-19  ...               49.09                            49.09
#
#    PROMO_QTY  PROMO_AMT  SUM_AMT_GAP ITEMGROUP CATEGORY_ID  \
# 18   46620.0   23310.00     93240.00   Spirits        LLS1
# 19   23310.0   69930.00     93240.00   Spirits        LLS1
#
#                                      PAF_LINK_SUGGEST  \
# 18                                               None
# 19  Z:\RA\PAF\LL PAF 02\PAF\2020-09-24 053206_DIAG...
#
#                                         EMAIL_SUGGEST CLASSIFY_AMOUNT
# 18                                               None
# 19  Z:\RA\PAF\LL PAF 02\Email\re bundy 1l bm% for ...
#
# [2 rows x 31 columns]
#    CLASSIFY_CLAIM CLASSIFY_STATE VENDOR_NUMBER      VENDOR_NAME BRANDID  \
# 20            PRO       national         47651  DIAGEO AUST LTD      1C
# 21            PRO       national         47651  DIAGEO AUST LTD      1C
# 22            PRO       national         47651  DIAGEO AUST LTD      1C
#
#      ITEMID                  ITEMNAME MULTIPLIER_NUM REBATE_ENTITLEMENT_NUM  \
# 20  6593222  BUNDABERG UP RUM 1 LITRE           1.00                   None
# 21  6593222  BUNDABERG UP RUM 1 LITRE           1.00                   None
# 22  6593222  BUNDABERG UP RUM 1 LITRE           1.00                   None
#
#      STARTDATE  ... PROMO_PRICE_SUGGEST PRICE_ACTUAL_LESS_THAN_PROMO_EXC  \
# 20  2021-04-21  ...               49.09                            49.01
# 21  2021-04-21  ...               49.09                            49.01
# 22  2021-04-21  ...               49.09                            49.01
#
#    PROMO_QTY  PROMO_AMT  SUM_AMT_GAP ITEMGROUP CATEGORY_ID  \
# 20    1865.0     932.50      5949.35   Spirits        1CS1
# 21    1865.0    2797.50      5949.35   Spirits        1CS1
# 22    1865.0    2219.35      5949.35   Spirits        1CS1
#
#                                      PAF_LINK_SUGGEST  \
# 20                                               None
# 21                                               None
# 22  https://myprofectus.sharepoint.com/:f:/r/sites...
#
#                                         EMAIL_SUGGEST CLASSIFY_AMOUNT
# 20                                               None    _LESSTHAN20K
# 21                                               None    _LESSTHAN20K
# 22  https://myprofectus.sharepoint.com/:f:/r/sites...    _LESSTHAN20K
#
# [3 rows x 31 columns]
#    CLASSIFY_CLAIM CLASSIFY_STATE VENDOR_NUMBER      VENDOR_NAME BRANDID  \
# 23            PRO       national         47651  DIAGEO AUST LTD      VC
# 32            PRO       national         47651  DIAGEO AUST LTD      VC
# 34            PRO       national         47651  DIAGEO AUST LTD      VC
# 35            PRO       national         47651  DIAGEO AUST LTD      VC
# 36            PRO       national         47651  DIAGEO AUST LTD      VC
# 37            PRO       national         47651  DIAGEO AUST LTD      VC
# 38            PRO       national         47651  DIAGEO AUST LTD      VC
# 40            PRO       national         47651  DIAGEO AUST LTD      VC
# 41            PRO       national         47651  DIAGEO AUST LTD      VC
# 44            PRO       national         47651  DIAGEO AUST LTD      VC
# 48            PRO       national         47651  DIAGEO AUST LTD      VC
# 49            PRO       national         47651  DIAGEO AUST LTD      VC
# 50            PRO       national         47651  DIAGEO AUST LTD      VC
# 54            PRO       national         47651  DIAGEO AUST LTD      VC
#
#      ITEMID                                        ITEMNAME MULTIPLIER_NUM  \
# 23  1389499  TALISKER STORM SINGLE MALT SCOTCH WHISKY 700ML           1.00
# 32  3260777                         TANQUERAY SEVILLA 700ML           1.00
# 34    33961               BAILEYS IRISH CREAM LIQUEUR 700ML           1.00
# 35    33961               BAILEYS IRISH CREAM LIQUEUR 700ML           1.00
# 36  3466820  SINGLETON MALT MASTER'S SELECTION WHISKY 700ML           1.00
# 37  3544027         MORTLACH 12 YO SINGLE MALT WHISKY 750ML           1.00
# 38  3544027         MORTLACH 12 YO SINGLE MALT WHISKY 750ML           1.00
# 40  3628149   BUNDABERG MASTER DISTILLERS' SOLERA RUM 700ML           1.00
# 41  3677574    SMIRNOFF INFUSIONS PASSIONFRUIT & LIME 700ML           1.00
# 44  3898325                GORDONS SICILIAN LEMON GIN 700ML           1.00
# 48  5361232                     TANQUERAY NO. TEN GIN 750ML           1.00
# 49  5361232                     TANQUERAY NO. TEN GIN 750ML           1.00
# 50  5362122                               CIROC VODKA 750ML           1.00
# 54  6105431         DIMPLE 12YO BLENDED SCOTCH WHISKY 700ML           1.00
#
#    REBATE_ENTITLEMENT_NUM   STARTDATE  ... PROMO_PRICE_SUGGEST  \
# 23                   None  2021-04-28  ...               70.00
# 32                   None  2021-04-28  ...               60.00
# 34                   None  2021-04-28  ...               26.36
# 35                   None  2021-04-28  ...               26.36
# 36                   None  2021-04-28  ...               50.00
# 37                   None  2021-04-28  ...               86.36
# 38                   None  2021-04-28  ...               86.36
# 40                   None  2021-04-28  ...              136.36
# 41                   None  2021-04-28  ...               30.00
# 44                   None  2021-04-28  ...               40.91
# 48                   None  2021-04-28  ...               61.82
# 49                   None  2021-04-28  ...               61.82
# 50                   None  2021-04-28  ...               65.45
# 54                   None  2021-04-28  ...               42.73
#
#    PRICE_ACTUAL_LESS_THAN_PROMO_EXC PROMO_QTY  PROMO_AMT  SUM_AMT_GAP  \
# 23                            70.00      -3.0     -17.22      1293.44
# 32                            58.33      51.0     216.75      1293.44
# 34                            25.92       4.0       7.12      1293.44
# 35                            25.92       2.0       4.96      1293.44
# 36                            45.45       1.0       3.87      1293.44
# 37                            72.73       0.0       0.00      1293.44
# 38                            72.73       0.0       0.00      1293.44
# 40                           136.36       2.0      10.66      1293.44
# 41                            29.96     108.0     180.36      1293.44
# 44                             None       NaN       None      1293.44
# 48                            59.20      26.0     222.82      1293.44
# 49                            59.20      26.0     216.32      1293.44
# 50                            65.45      97.0     442.32      1293.44
# 54                            41.82       1.0       5.48      1293.44
#
#    ITEMGROUP CATEGORY_ID                                   PAF_LINK_SUGGEST  \
# 23   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 32   Spirits        VCS1                                               None
# 34   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 35   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 36   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 37   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 38   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 40   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 41   Spirits        VCS1                                               None
# 44   Spirits        VCS1                                               None
# 48   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 49   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 50   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 54   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
#
#                                         EMAIL_SUGGEST CLASSIFY_AMOUNT
# 23  https://myprofectus.sharepoint.com/:f:/r/sites...    _LESSTHAN20K
# 32                                               None    _LESSTHAN20K
# 34  https://myprofectus.sharepoint.com/:f:/r/sites...    _LESSTHAN20K
# 35  https://myprofectus.sharepoint.com/:f:/r/sites...    _LESSTHAN20K
# 36  https://myprofectus.sharepoint.com/:f:/r/sites...    _LESSTHAN20K
# 37  https://myprofectus.sharepoint.com/:f:/r/sites...    _LESSTHAN20K
# 38  https://myprofectus.sharepoint.com/:f:/r/sites...    _LESSTHAN20K
# 40  https://myprofectus.sharepoint.com/:f:/r/sites...    _LESSTHAN20K
# 41                                               None    _LESSTHAN20K
# 44                                               None    _LESSTHAN20K
# 48  https://myprofectus.sharepoint.com/:f:/r/sites...    _LESSTHAN20K
# 49  https://myprofectus.sharepoint.com/:f:/r/sites...    _LESSTHAN20K
# 50  https://myprofectus.sharepoint.com/:f:/r/sites...    _LESSTHAN20K
# 54  https://myprofectus.sharepoint.com/:f:/r/sites...    _LESSTHAN20K
#
# [14 rows x 31 columns]
#    CLASSIFY_CLAIM CLASSIFY_STATE VENDOR_NUMBER      VENDOR_NAME BRANDID  \
# 24            PRO       national         47651  DIAGEO AUST LTD      VC
# 25            PRO       national         47651  DIAGEO AUST LTD      VC
# 26            PRO       national         47651  DIAGEO AUST LTD      VC
# 27            PRO       national         47651  DIAGEO AUST LTD      VC
# 28            PRO       national         47651  DIAGEO AUST LTD      VC
# 29            PRO       national         47651  DIAGEO AUST LTD      VC
# 30            PRO       national         47651  DIAGEO AUST LTD      VC
# 31            PRO       national         47651  DIAGEO AUST LTD      VC
# 33            PRO       national         47651  DIAGEO AUST LTD      VC
# 39            PRO       national         47651  DIAGEO AUST LTD      VC
# 42            PRO       national         47651  DIAGEO AUST LTD      VC
# 43            PRO       national         47651  DIAGEO AUST LTD      VC
# 45            PRO       national         47651  DIAGEO AUST LTD      VC
# 46            PRO       national         47651  DIAGEO AUST LTD      VC
# 47            PRO       national         47651  DIAGEO AUST LTD      VC
# 51            PRO       national         47651  DIAGEO AUST LTD      VC
# 52            PRO       national         47651  DIAGEO AUST LTD      VC
# 53            PRO       national         47651  DIAGEO AUST LTD      VC
# 55            PRO       national         47651  DIAGEO AUST LTD      VC
# 56            PRO       national         47651  DIAGEO AUST LTD      VC
# 57            PRO       national         47651  DIAGEO AUST LTD      VC
#
#      ITEMID                                           ITEMNAME MULTIPLIER_NUM  \
# 24    14182                              PIMM'S NO 1 CUP 700ML           1.00
# 25  1979710                BUNDABERG MDC SMALL BATCH RUM 700ML           1.00
# 26   215428                  BELLS BLENDED SCOTCH WHISKY 700ML           1.00
# 27  2481191                  TALISKER SKYE SCOTCH WHISKY 700ML           1.00
# 28    26970      JOHNNIE WALKER BLUE LABEL SCOTCH WHISKY 700ML           1.00
# 29  2804450  LAGAVULIN 8YO ANNIVERSARY EDITION SCOTCH WHISK...           1.00
# 30    30663  JOHNNIE WALKER BLACK LABEL 12YO SCOTCH WHISKY ...           1.00
# 31    32247                             BUNDABERG UP RUM 700ML           1.00
# 33    32872                                TANQUERAY GIN 700ML           1.00
# 39  3581792                            GORDON'S PINK GIN 700ML           1.00
# 42  3681571                           SMIRNOFF RED VODKA 700ML           1.00
# 43  3681607                              SMIRNOFF RED VODKA 1L           1.00
# 45   433273     JOHNNIE WALKER RED LABEL SCOTCH WHISKY 1 LITRE           1.00
# 46    45049       JOHNNIE WALKER RED LABEL SCOTCH WHISKY 700ML           1.00
# 47   497640                        BAILEYS IRISH CREAM 1 LITRE           1.00
# 51   540209                            GORDONS DRY GIN 1 LITRE           1.00
# 52  5677270                   CAPTAIN MORGAN SPICED GOLD 700ML           1.00
# 53   569651                                  GORDONS GIN 700ML           1.00
# 55    78597          OBAN 14YO SINGLE MALT SCOTCH WHISKY 700ML           1.00
# 56    78603    DALWHINNIE 15YO SINGLE MALT SCOTCH WHISKY 700ML           1.00
# 57  8727148      CAOL ILA 12YO SINGLE MALT SCOTCH WHISKY 700ML           1.00
#
#    REBATE_ENTITLEMENT_NUM   STARTDATE  ... PROMO_PRICE_SUGGEST  \
# 24                   1.80  2021-04-28  ...               32.73
# 25                   6.61  2021-04-28  ...               50.91
# 26                   0.10  2021-04-28  ...               31.82
# 27                  10.87  2021-04-28  ...               63.64
# 28                   8.00  2021-04-28  ...              181.82
# 29                   1.00  2021-04-28  ...               87.26
# 30                   6.65  2021-04-28  ...               41.82
# 31                   2.67  2021-04-28  ...               34.55
# 33                   1.76  2021-04-28  ...               41.82
# 39                   0.92  2021-04-28  ...               40.91
# 42                   1.70  2021-04-28  ...               34.55
# 43                   2.10  2021-04-28  ...               49.09
# 45                   1.10  2021-04-28  ...               50.00
# 46                   1.20  2021-04-28  ...               34.55
# 47                   2.00  2021-04-28  ...               36.36
# 51                   5.68  2021-04-28  ...               50.00
# 52                   1.33  2021-04-28  ...               34.55
# 53                   4.59  2021-04-28  ...               34.55
# 55                  13.26  2021-04-28  ...               94.55
# 56                  12.85  2021-04-28  ...               72.73
# 57                   5.33  2021-04-28  ...               87.27
#
#    PRICE_ACTUAL_LESS_THAN_PROMO_EXC PROMO_QTY  PROMO_AMT  SUM_AMT_GAP  \
# 24                            32.73     121.0     217.80     46360.95
# 25                            50.85      46.0     304.06     46360.95
# 26                            31.80     914.0      91.40     46360.95
# 27                            63.64     432.0    4695.84     46360.95
# 28                           181.82     134.0    1203.32     46360.95
# 29                            87.27      82.0      82.00     46360.95
# 30                            41.76    1349.0    8970.85     46360.95
# 31                            34.10     359.0     779.03     46360.95
# 33                            41.81    1649.0    2902.24     46360.95
# 39                            40.86     187.0     172.04     46360.95
# 42                            34.09     529.0     989.23     46360.95
# 43                            49.05    1517.0    3185.70     46360.95
# 45                            50.00     607.0     667.70     46360.95
# 46                            34.09     667.0     747.04     46360.95
# 47                            36.34    1433.0    2866.00     46360.95
# 51                            49.96     604.0    3430.72     46360.95
# 52                            34.11     214.0     190.46     46360.95
# 53                            34.10     808.0    2092.72     46360.95
# 55                            94.55     314.0    4163.64     46360.95
# 56                            72.60     609.0    7825.65     46360.95
# 57                            87.27     147.0     783.51     46360.95
#
#    ITEMGROUP CATEGORY_ID                                   PAF_LINK_SUGGEST  \
# 24   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 25   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 26   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 27   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 28   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 29   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 30   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 31   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 33   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 39   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 42   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 43   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 45   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 46   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 47   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 51   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 52   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 53   Spirits        VCS1  Z:\RA\PAF\LL Monthly\28022021-01052021\PAF\Dia...
# 55   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 56   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 57   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
#
#                                         EMAIL_SUGGEST CLASSIFY_AMOUNT
# 24  https://myprofectus.sharepoint.com/:f:/r/sites...
# 25  https://myprofectus.sharepoint.com/:f:/r/sites...
# 26  https://myprofectus.sharepoint.com/:f:/r/sites...
# 27  https://myprofectus.sharepoint.com/:f:/r/sites...
# 28  https://myprofectus.sharepoint.com/:f:/r/sites...
# 29  https://myprofectus.sharepoint.com/:f:/r/sites...
# 30  https://myprofectus.sharepoint.com/:f:/r/sites...
# 31  https://myprofectus.sharepoint.com/:f:/r/sites...
# 33  https://myprofectus.sharepoint.com/:f:/r/sites...
# 39  https://myprofectus.sharepoint.com/:f:/r/sites...
# 42  https://myprofectus.sharepoint.com/:f:/r/sites...
# 43  https://myprofectus.sharepoint.com/:f:/r/sites...
# 45  https://myprofectus.sharepoint.com/:f:/r/sites...
# 46  https://myprofectus.sharepoint.com/:f:/r/sites...
# 47  https://myprofectus.sharepoint.com/:f:/r/sites...
# 51  https://myprofectus.sharepoint.com/:f:/r/sites...
# 52  https://myprofectus.sharepoint.com/:f:/r/sites...
# 53  Z:\RA\PAF\LL Monthly\28022021-01052021\Email\f...
# 55  https://myprofectus.sharepoint.com/:f:/r/sites...
# 56  https://myprofectus.sharepoint.com/:f:/r/sites...
# 57  https://myprofectus.sharepoint.com/:f:/r/sites...
#
# [21 rows x 31 columns]
#    CLASSIFY_CLAIM CLASSIFY_STATE VENDOR_NUMBER      VENDOR_NAME BRANDID  \
# 58            PRO       national         47651  DIAGEO AUST LTD      1C
# 59            PRO       national         47651  DIAGEO AUST LTD      LL
#
#      ITEMID                                      ITEMNAME MULTIPLIER_NUM  \
# 58  4395148  JOHNNIE WALKER SINGLE ORIGIN HIGHLANDS 700ML           1.00
# 59  4395148  JOHNNIE WALKER SINGLE ORIGIN HIGHLANDS 700ML           1.00
#
#    REBATE_ENTITLEMENT_NUM   STARTDATE  ... PROMO_PRICE_SUGGEST  \
# 58                   9.26  2021-05-03  ...               50.00
# 59                   9.26  2021-05-03  ...               50.91
#
#    PRICE_ACTUAL_LESS_THAN_PROMO_EXC PROMO_QTY  PROMO_AMT  SUM_AMT_GAP  \
# 58                            49.81    1310.0   12130.60     27446.64
# 59                            49.94    1654.0   15316.04     27446.64
#
#    ITEMGROUP CATEGORY_ID  PAF_LINK_SUGGEST EMAIL_SUGGEST CLASSIFY_AMOUNT
# 58   Spirits        1CS1              None          None
# 59   Spirits        LLS1              None          None
#
# [2 rows x 31 columns]
#    CLASSIFY_CLAIM CLASSIFY_STATE VENDOR_NUMBER      VENDOR_NAME BRANDID  \
# 60            PRO       national         47651  DIAGEO AUST LTD      1C
# 61            PRO       national         47651  DIAGEO AUST LTD      LL
# 65            PRO       national         47651  DIAGEO AUST LTD      1C
# 66            PRO       national         47651  DIAGEO AUST LTD      1C
# 71            PRO       national         47651  DIAGEO AUST LTD      LL
# 78            PRO       national         47651  DIAGEO AUST LTD      1C
# 81            PRO       national         47651  DIAGEO AUST LTD      1C
# 83            PRO       national         47651  DIAGEO AUST LTD      1C
# 87            PRO       national         47651  DIAGEO AUST LTD      LL
# 88            PRO       national         47651  DIAGEO AUST LTD      LL
# 93            PRO       national         47651  DIAGEO AUST LTD      1C
# 94            PRO       national         47651  DIAGEO AUST LTD      1C
# 95            PRO       national         47651  DIAGEO AUST LTD      LL
#
#      ITEMID                                       ITEMNAME MULTIPLIER_NUM  \
# 60  1055008              BUNDABERG MUTINY SPICED RUM 700ML           1.00
# 61  1055008              BUNDABERG MUTINY SPICED RUM 700ML           1.00
# 65  2481191              TALISKER SKYE SCOTCH WHISKY 700ML           1.00
# 66  2840206                 BUNDABERG 12YO BLACK RUM 700ML           1.00
# 71    32872                            TANQUERAY GIN 700ML           1.00
# 78  3581792                        GORDON'S PINK GIN 700ML           1.00
# 81  3677541  SMIRNOFF INFUSIONS CUCUMBER LIME & MINT 700ML           1.00
# 83  3677574   SMIRNOFF INFUSIONS PASSIONFRUIT & LIME 700ML           1.00
# 87  4267374         GORDONS MEDITERANNEAN ORANGE GIN 700ML           1.00
# 88  4267374         GORDONS MEDITERANNEAN ORANGE GIN 700ML           1.00
# 93    46916    HAIG DIMPLE 15 YEAR OLD SCOTCH WHISKY 700ML           1.00
# 94    46916    HAIG DIMPLE 15 YEAR OLD SCOTCH WHISKY 700ML           1.00
# 95    46916    HAIG DIMPLE 15 YEAR OLD SCOTCH WHISKY 700ML           1.00
#
#    REBATE_ENTITLEMENT_NUM   STARTDATE  ... PROMO_PRICE_SUGGEST  \
# 60                   None  2021-05-05  ...               36.36
# 61                   None  2021-05-05  ...               37.27
# 65                   None  2021-05-05  ...               63.64
# 66                   None  2021-05-05  ...               47.27
# 71                   None  2021-05-05  ...               41.82
# 78                   None  2021-05-05  ...               40.91
# 81                   None  2021-05-05  ...               25.45
# 83                   None  2021-05-05  ...               25.45
# 87                   None  2021-05-05  ...               41.82
# 88                   None  2021-05-05  ...               41.82
# 93                   None  2021-05-05  ...               50.00
# 94                   None  2021-05-05  ...               50.00
# 95                   None  2021-05-05  ...               54.55
#
#    PRICE_ACTUAL_LESS_THAN_PROMO_EXC PROMO_QTY  PROMO_AMT  SUM_AMT_GAP  \
# 60                            35.09      10.0       7.50      3544.33
# 61                            35.38      84.0      63.00      3544.33
# 65                            63.64       8.0      86.96      3544.33
# 66                            47.27       9.0       4.23      3544.33
# 71                            41.03      43.0      54.18      3544.33
# 78                            40.02     224.0     206.08      3544.33
# 81                            25.45     108.0     180.36      3544.33
# 83                            24.12     196.0     327.32      3544.33
# 87                            40.92     201.0     106.53      3544.33
# 88                            40.92     201.0     166.83      3544.33
# 93                            48.82     246.0    1596.54      3544.33
# 94                            48.82      82.0     563.34      3544.33
# 95                            48.90      43.0     181.46      3544.33
#
#    ITEMGROUP CATEGORY_ID                                   PAF_LINK_SUGGEST  \
# 60   Spirits        1CS1  Z:\RA\PAF\LL Monthly\01052021-01062021\PAF\Dia...
# 61   Spirits        LLS1                                               None
# 65   Spirits        1CS1  Z:\RA\PAF\LL Monthly\01052021-01062021\PAF\Dia...
# 66   Spirits        1CS1  Z:\RA\PAF\LL Monthly\01052021-01062021\PAF\Dia...
# 71   Spirits        LLS1                                               None
# 78   Spirits        1CS1  Z:\RA\PAF\LL Monthly\21112020-28022021-new\LL_...
# 81   Spirits        1CS1  Z:\RA\PAF\LL Monthly\01052021-01062021\PAF\Dia...
# 83   Spirits        1CS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 87   Spirits        LLS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 88   Spirits        LLS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 93   Spirits        1CS1  Z:\RA\PAF\LL Monthly\28022021-01052021\PAF\Dia...
# 94   Spirits        1CS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 95   Spirits        LLS1  Z:\RA\PAF\LL Monthly\21112020-28022021-new\LL_...
#
#                                         EMAIL_SUGGEST CLASSIFY_AMOUNT
# 60  Z:\RA\PAF\LL Monthly\01052021-01062021\Email\r...    _LESSTHAN20K
# 61                                               None    _LESSTHAN20K
# 65  Z:\RA\PAF\LL Monthly\01052021-01062021\Email\r...    _LESSTHAN20K
# 66  Z:\RA\PAF\LL Monthly\01052021-01062021\Email\r...    _LESSTHAN20K
# 71                                               None    _LESSTHAN20K
# 78  Z:\RA\PAF\LL Monthly\21112020-28022021-new\LL_...    _LESSTHAN20K
# 81  Z:\RA\PAF\LL Monthly\01052021-01062021\Email\r...    _LESSTHAN20K
# 83  https://myprofectus.sharepoint.com/:f:/r/sites...    _LESSTHAN20K
# 87  https://myprofectus.sharepoint.com/:f:/r/sites...    _LESSTHAN20K
# 88  https://myprofectus.sharepoint.com/:f:/r/sites...    _LESSTHAN20K
# 93  Z:\RA\PAF\LL Monthly\28022021-01052021\Email\j...    _LESSTHAN20K
# 94  https://myprofectus.sharepoint.com/:f:/r/sites...    _LESSTHAN20K
# 95  Z:\RA\PAF\LL Monthly\21112020-28022021-new\LL_...    _LESSTHAN20K
#
# [13 rows x 31 columns]
#     CLASSIFY_CLAIM CLASSIFY_STATE VENDOR_NUMBER      VENDOR_NAME BRANDID  \
# 62             PRO       national         47651  DIAGEO AUST LTD      1C
# 63             PRO       national         47651  DIAGEO AUST LTD      1C
# 64             PRO       national         47651  DIAGEO AUST LTD      LL
# 67             PRO       national         47651  DIAGEO AUST LTD      LL
# 68             PRO       national         47651  DIAGEO AUST LTD      1C
# 69             PRO       national         47651  DIAGEO AUST LTD      1C
# 70             PRO       national         47651  DIAGEO AUST LTD      LL
# 72             PRO       national         47651  DIAGEO AUST LTD      1C
# 73             PRO       national         47651  DIAGEO AUST LTD      LL
# 74             PRO       national         47651  DIAGEO AUST LTD      1C
# 75             PRO       national         47651  DIAGEO AUST LTD      LL
# 76             PRO       national         47651  DIAGEO AUST LTD      1C
# 77             PRO       national         47651  DIAGEO AUST LTD      LL
# 79             PRO       national         47651  DIAGEO AUST LTD      LL
# 80             PRO       national         47651  DIAGEO AUST LTD      1C
# 82             PRO       national         47651  DIAGEO AUST LTD      LL
# 84             PRO       national         47651  DIAGEO AUST LTD      1C
# 85             PRO       national         47651  DIAGEO AUST LTD      LL
# 86             PRO       national         47651  DIAGEO AUST LTD      LL
# 89             PRO       national         47651  DIAGEO AUST LTD      1C
# 90             PRO       national         47651  DIAGEO AUST LTD      LL
# 91             PRO       national         47651  DIAGEO AUST LTD      1C
# 92             PRO       national         47651  DIAGEO AUST LTD      LL
# 96             PRO       national         47651  DIAGEO AUST LTD      1C
# 97             PRO       national         47651  DIAGEO AUST LTD      1C
# 98             PRO       national         47651  DIAGEO AUST LTD      LL
# 99             PRO       national         47651  DIAGEO AUST LTD      1C
# 100            PRO       national         47651  DIAGEO AUST LTD      LL
# 101            PRO       national         47651  DIAGEO AUST LTD      1C
# 102            PRO       national         47651  DIAGEO AUST LTD      LL
# 103            PRO       national         47651  DIAGEO AUST LTD      LL
#
#       ITEMID                                         ITEMNAME MULTIPLIER_NUM  \
# 62   1389499   TALISKER STORM SINGLE MALT SCOTCH WHISKY 700ML           1.00
# 63   2466187                CAPTAIN MORGAN SPICED RUM 1 LITRE           1.00
# 64   2466187                CAPTAIN MORGAN SPICED RUM 1 LITRE           1.00
# 67   3041343                                 TANQUERAY GIN 1L           1.00
# 68   3150928  JOHNNIE WALKER 18YO BLENDED SCOTCH WHISKY 700ML           1.00
# 69     32247                           BUNDABERG UP RUM 700ML           1.00
# 70     32247                           BUNDABERG UP RUM 700ML           1.00
# 72     33961                BAILEYS IRISH CREAM LIQUEUR 700ML           1.00
# 73     33961                BAILEYS IRISH CREAM LIQUEUR 700ML           1.00
# 74   3403874       BUNDABERG MDC SMALL BATCH SPICED RUM 700ML           1.00
# 75   3466819             DIMPLE 12YO BLENDED SCOTCH WHISKY 1L           1.00
# 76   3544027          MORTLACH 12 YO SINGLE MALT WHISKY 750ML           1.00
# 77   3544027          MORTLACH 12 YO SINGLE MALT WHISKY 750ML           1.00
# 79   3581792                          GORDON'S PINK GIN 700ML           1.00
# 80   3628127             COPPER DOG BLENDED MALT WHISKY 700ML           1.00
# 82   3677541    SMIRNOFF INFUSIONS CUCUMBER LIME & MINT 700ML           1.00
# 84   3681571                         SMIRNOFF RED VODKA 700ML           1.00
# 85   3681607                            SMIRNOFF RED VODKA 1L           1.00
# 86   3898325                 GORDONS SICILIAN LEMON GIN 700ML           1.00
# 89    433273   JOHNNIE WALKER RED LABEL SCOTCH WHISKY 1 LITRE           1.00
# 90    433273   JOHNNIE WALKER RED LABEL SCOTCH WHISKY 1 LITRE           1.00
# 91     45049     JOHNNIE WALKER RED LABEL SCOTCH WHISKY 700ML           1.00
# 92     45049     JOHNNIE WALKER RED LABEL SCOTCH WHISKY 700ML           1.00
# 96   5361232                      TANQUERAY NO. TEN GIN 750ML           1.00
# 97    540209                          GORDONS DRY GIN 1 LITRE           1.00
# 98    540209                          GORDONS DRY GIN 1 LITRE           1.00
# 99   6592999                          BUNDABERG RED RUM 700ML           1.00
# 100  6592999                          BUNDABERG RED RUM 700ML           1.00
# 101    78603  DALWHINNIE 15YO SINGLE MALT SCOTCH WHISKY 700ML           1.00
# 102  8705178  JOHNNIE WALKER DOUBLE BLACK SCOTCH WHISKY 700ML           1.00
# 103    94580    TALISKER 10YO SINGLE MALT SCOTCH WHISKY 700ML           1.00
#
#     REBATE_ENTITLEMENT_NUM   STARTDATE  ... PROMO_PRICE_SUGGEST  \
# 62                    5.74  2021-05-05  ...               68.18
# 63                    5.03  2021-05-05  ...               49.09
# 64                    5.03  2021-05-05  ...               49.09
# 67                    1.30  2021-05-05  ...               60.00
# 68                   12.09  2021-05-05  ...               87.27
# 69                    2.78  2021-05-05  ...               34.55
# 70                    2.18  2021-05-05  ...               37.27
# 72                    3.25  2021-05-05  ...               27.27
# 73                    1.43  2021-05-05  ...               28.18
# 74                    5.64  2021-05-05  ...               50.91
# 75                    2.96  2021-05-05  ...               60.00
# 76                    0.42  2021-05-05  ...               88.18
# 77                    0.83  2021-05-05  ...               88.18
# 79                    0.92  2021-05-05  ...               40.91
# 80                    3.77  2021-05-05  ...               45.45
# 82                    1.67  2021-05-05  ...               22.73
# 84                    1.83  2021-05-05  ...               34.55
# 85                    2.19  2021-05-05  ...               48.18
# 86                    0.44  2021-05-05  ...               41.82
# 89                    1.67  2021-05-05  ...               47.27
# 90                    1.67  2021-05-05  ...               47.27
# 91                    1.73  2021-05-05  ...               34.55
# 92                    1.12  2021-05-05  ...               37.27
# 96                    8.32  2021-05-05  ...               59.09
# 97                    2.35  2021-05-05  ...               50.00
# 98                    2.35  2021-05-05  ...               50.00
# 99                    2.30  2021-05-05  ...               34.55
# 100                   1.67  2021-05-05  ...               35.45
# 101                  10.35  2021-05-05  ...               80.91
# 102                   3.73  2021-05-05  ...               49.09
# 103                   1.02  2021-05-05  ...               79.09
#
#     PRICE_ACTUAL_LESS_THAN_PROMO_EXC PROMO_QTY  PROMO_AMT  SUM_AMT_GAP  \
# 62                             68.18     642.0    3685.08    309241.11
# 63                             49.07    2141.0   10769.23    309241.11
# 64                             49.09    7394.0   37191.82    309241.11
# 67                             59.52    5529.0    7187.70    309241.11
# 68                             87.27     455.0    5500.95    309241.11
# 69                             33.58    1355.0    2953.90    309241.11
# 70                             34.58    4663.0    4709.63    309241.11
# 72                             26.61    3465.0   10291.05    309241.11
# 73                             27.63   13611.0   19463.73    309241.11
# 74                             50.91     419.0    2363.16    309241.11
# 75                             55.44    1294.0    3830.24    309241.11
# 76                             88.18      39.0      16.38    309241.11
# 77                             88.17     386.0     320.38    309241.11
# 79                             40.91    5690.0    5234.80    309241.11
# 80                             45.45     609.0    2295.93    309241.11
# 82                             20.02     515.0     566.50    309241.11
# 84                             34.54    5588.0   10226.04    309241.11
# 85                             48.18   26596.0   58245.24    309241.11
# 86                             40.94     674.0     202.20    309241.11
# 89                             47.23    1738.0    2902.46    309241.11
# 90                             47.27   20655.0   34493.85    309241.11
# 91                             33.65    1573.0    2516.80    309241.11
# 92                             34.52    3523.0    2466.10    309241.11
# 96                             59.09     562.0    4675.84    309241.11
# 97                             49.96    3520.0    8272.00    309241.11
# 98                             49.99   10505.0   24686.75    309241.11
# 99                             25.68       9.0      20.70    309241.11
# 100                            35.14    4426.0    7391.42    309241.11
# 101                            80.91     424.0    4388.40    309241.11
# 102                            47.90    5659.0   29257.03    309241.11
# 103                            79.07    1154.0    3115.80    309241.11
#
#     ITEMGROUP CATEGORY_ID                                   PAF_LINK_SUGGEST  \
# 62    Spirits        1CS1                                               None
# 63    Spirits        1CS1  Z:\RA\PAF\LL Monthly\28022021-01052021\PAF\Dia...
# 64    Spirits        LLS1  Z:\RA\PAF\LL Monthly\28022021-01052021\PAF\Dia...
# 67    Spirits        LLS1  Z:\RA\PAF\LL Monthly\01052021-01062021\PAF\Dia...
# 68    Spirits        1CS1                                               None
# 69    Spirits        1CS1  Z:\RA\PAF\LL Monthly\01052021-01062021\PAF\Dia...
# 70    Spirits        LLS1                                               None
# 72    Spirits        1CS1  Z:\RA\PAF\LL Monthly\01052021-01062021\PAF\Dia...
# 73    Spirits        LLS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 74    Spirits        1CS1  Z:\RA\PAF\LL Monthly\01052021-01062021\PAF\Dia...
# 75    Spirits        LLS1  Z:\RA\PAF\LL PAF 02\PAF\2020-10-20 224513_DIAG...
# 76    Spirits        1CS1  Z:\RA\PAF\LL Monthly\28022021-01052021\PAF\Dia...
# 77    Spirits        LLS1  Z:\RA\PAF\LL Monthly\28022021-01052021\PAF\Dia...
# ...
# 117     53415.84   Spirits        1CS1
# 118     53415.84   Spirits        VCS1
# 120     53415.84   Spirits        1CS1
# 121     53415.84   Spirits        LLS1
# 122     53415.84   Spirits        LLS1
#
#                                       PAF_LINK_SUGGEST  \
# 114  https://myprofectus.sharepoint.com/:f:/r/sites...
# 115                                               None
# 117  https://myprofectus.sharepoint.com/:f:/r/sites...
# 118  https://myprofectus.sharepoint.com/:f:/r/sites...
# 120  Z:\RA\PAF\LL Monthly\28022021-01052021\PAF\Dia...
# 121  Z:\RA\PAF\LL Monthly\28022021-01052021\PAF\Dia...
# 122  Z:\RA\PAF\LL Monthly\28022021-01052021\PAF\Dia...
#
#                                          EMAIL_SUGGEST CLASSIFY_AMOUNT
# 114  https://myprofectus.sharepoint.com/:f:/r/sites...
# 115                                               None
# 117  https://myprofectus.sharepoint.com/:f:/r/sites...
# 118  https://myprofectus.sharepoint.com/:f:/r/sites...
# 120  Z:\RA\PAF\LL Monthly\28022021-01052021\Email\c...
# 121  Z:\RA\PAF\LL Monthly\28022021-01052021\Email\d...
# 122  Z:\RA\PAF\LL Monthly\28022021-01052021\Email\d...
#
# [7 rows x 31 columns]
#     CLASSIFY_CLAIM CLASSIFY_STATE VENDOR_NUMBER      VENDOR_NAME BRANDID  \
# 123            PRO       national         47651  DIAGEO AUST LTD      1C
#
#       ITEMID                                 ITEMNAME MULTIPLIER_NUM  \
# 123  6105431  DIMPLE 12YO BLENDED SCOTCH WHISKY 700ML           1.00
#
#     REBATE_ENTITLEMENT_NUM   STARTDATE  ... PROMO_PRICE_SUGGEST  \
# 123                   2.44  2021-05-21  ...               40.91
#
#     PRICE_ACTUAL_LESS_THAN_PROMO_EXC PROMO_QTY  PROMO_AMT  SUM_AMT_GAP  \
# 123                            40.91    1570.0    3830.80      3830.80
#
#     ITEMGROUP CATEGORY_ID                                   PAF_LINK_SUGGEST  \
# 123   Spirits        1CS1  https://myprofectus.sharepoint.com/:f:/r/sites...
#
#                                          EMAIL_SUGGEST CLASSIFY_AMOUNT
# 123  https://myprofectus.sharepoint.com/:f:/r/sites...    _LESSTHAN20K
#
# [1 rows x 31 columns]
#     CLASSIFY_CLAIM CLASSIFY_STATE VENDOR_NUMBER      VENDOR_NAME BRANDID  \
# 124            PRO       national         47651  DIAGEO AUST LTD      VC
# 125            PRO       national         47651  DIAGEO AUST LTD      VC
#
#     ITEMID                                       ITEMNAME MULTIPLIER_NUM  \
# 124  94580  TALISKER 10YO SINGLE MALT SCOTCH WHISKY 700ML           1.00
# 125  94580                                           None           1.00
#
#     REBATE_ENTITLEMENT_NUM   STARTDATE  ... PROMO_PRICE_SUGGEST  \
# 124                   5.00  2021-05-24  ...               72.73
# 125                   5.00  2021-05-24  ...               72.73
#
#     PRICE_ACTUAL_LESS_THAN_PROMO_EXC PROMO_QTY  PROMO_AMT  SUM_AMT_GAP  \
# 124                            72.73      68.0     409.36       818.72
# 125                            72.73      68.0     409.36       818.72
#
#     ITEMGROUP CATEGORY_ID                                   PAF_LINK_SUGGEST  \
# 124   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
# 125   Spirits        VCS1  https://myprofectus.sharepoint.com/:f:/r/sites...
#
#                                          EMAIL_SUGGEST CLASSIFY_AMOUNT
# 124  https://myprofectus.sharepoint.com/:f:/r/sites...    _LESSTHAN20K
# 125  https://myprofectus.sharepoint.com/:f:/r/sites...    _LESSTHAN20K
#
# [2 rows x 31 columns]
#     CLASSIFY_CLAIM CLASSIFY_STATE VENDOR_NUMBER      VENDOR_NAME BRANDID  \
# 126            PRO       national         47651  DIAGEO AUST LTD      1C
# 127            PRO       national         47651  DIAGEO AUST LTD      1C
#
#     ITEMID                                       ITEMNAME MULTIPLIER_NUM  \
# 126  94580  TALISKER 10YO SINGLE MALT SCOTCH WHISKY 700ML           1.00
# 127  94580  TALISKER 10YO SINGLE MALT SCOTCH WHISKY 700ML           1.00
#
#     REBATE_ENTITLEMENT_NUM   STARTDATE  ... PROMO_PRICE_SUGGEST  \
# 126                   None  2021-05-27  ...               79.09
# 127                   None  2021-05-27  ...               79.09
#
#     PRICE_ACTUAL_LESS_THAN_PROMO_EXC PROMO_QTY  PROMO_AMT  SUM_AMT_GAP  \
# 126                            74.24      22.0      59.40        86.46
# 127                            74.24      11.0      27.06        86.46
#
#     ITEMGROUP CATEGORY_ID                                   PAF_LINK_SUGGEST  \
# 126   Spirits        1CS1  Z:\RA\PAF\LL Monthly\28022021-01052021\PAF\Dia...
# 127   Spirits        1CS1  https://myprofectus.sharepoint.com/:f:/r/sites...
#
#                                          EMAIL_SUGGEST CLASSIFY_AMOUNT
# 126  Z:\RA\PAF\LL Monthly\28022021-01052021\Email\j...    _LESSTHAN20K
# 127  https://myprofectus.sharepoint.com/:f:/r/sites...    _LESSTHAN20K
#
# [2 rows x 31 columns]
#     CLASSIFY_CLAIM CLASSIFY_STATE VENDOR_NUMBER      VENDOR_NAME BRANDID  \
# 128            PRO       national         47651  DIAGEO AUST LTD      1C
# 129            PRO       national         47651  DIAGEO AUST LTD      1C
# 130            PRO       national         47651  DIAGEO AUST LTD      1C
# 131            PRO       national         47651  DIAGEO AUST LTD      1C
# 132            PRO       national         47651  DIAGEO AUST LTD      1C
# 133            PRO       national         47651  DIAGEO AUST LTD      1C
#
#       ITEMID                                           ITEMNAME  \
# 128  2466187                  CAPTAIN MORGAN SPICED RUM 1 LITRE
# 129  2466187                  CAPTAIN MORGAN SPICED RUM 1 LITRE
# 130  6105431            DIMPLE 12YO BLENDED SCOTCH WHISKY 700ML
# 131  6105431            DIMPLE 12YO BLENDED SCOTCH WHISKY 700ML
# 132    78603    DALWHINNIE 15YO SINGLE MALT SCOTCH WHISKY 700ML
# 133   926379  JOHNNIE WALKER BLACK LABEL 12YO SCOTCH WHISKY ...
#
#     MULTIPLIER_NUM REBATE_ENTITLEMENT_NUM   STARTDATE  ...  \
# 128           1.00                   None  2021-06-02  ...
# 129           1.00                   None  2021-06-02  ...
# 130           1.00                   None  2021-06-02  ...
# 131           1.00                   None  2021-06-02  ...
# 132           1.00                   None  2021-06-02  ...
# 133           1.00                   None  2021-06-02  ...
#
#     PROMO_PRICE_SUGGEST PRICE_ACTUAL_LESS_THAN_PROMO_EXC PROMO_QTY  PROMO_AMT  \
# 128               48.18                            48.18     143.0     504.79
# 129               48.18                            48.18     143.0     743.60
# 130               40.00                            40.00     301.0     903.00
# 131               40.00                            40.00     602.0    2094.96
# 132               90.00                            87.98       9.0      93.15
# 133               72.73                            69.33      24.0     150.48
#
#      SUM_AMT_GAP ITEMGROUP CATEGORY_ID  \
# 128      4489.98   Spirits        1CS1
# 129      4489.98   Spirits        1CS1
# 130      4489.98   Spirits        1CS1
# 131      4489.98   Spirits        1CS1
# 132      4489.98   Spirits        1CS1
# 133      4489.98   Spirits        1CS1
#
#                                       PAF_LINK_SUGGEST  \
# 128                                               None
# 129  Z:\RA\PAF\LL Monthly\01052021-01062021\PAF\Dia...
# 130  Z:\RA\PAF\LL Monthly\01052021-01062021\PAF\Dia...
# 131                                               None
# 132                                               None
# 133                                               None
#
#                                          EMAIL_SUGGEST CLASSIFY_AMOUNT
# 128                                               None    _LESSTHAN20K
# 129  Z:\RA\PAF\LL Monthly\01052021-01062021\Email\r...    _LESSTHAN20K
# 130  Z:\RA\PAF\LL Monthly\01052021-01062021\Email\r...    _LESSTHAN20K
# 131                                               None    _LESSTHAN20K
# 132                                               None    _LESSTHAN20K
# 133                                               None    _LESSTHAN20K
#
# [6 rows x 31 columns]
#     CLASSIFY_CLAIM CLASSIFY_STATE VENDOR_NUMBER      VENDOR_NAME BRANDID  \
# 134            PRO       national         47651  DIAGEO AUST LTD      VC
#
#      ITEMID                 ITEMNAME MULTIPLIER_NUM REBATE_ENTITLEMENT_NUM  \
# 134  540209  GORDONS DRY GIN 1 LITRE           1.00                   None
#
#       STARTDATE  ... PROMO_PRICE_SUGGEST PRICE_ACTUAL_LESS_THAN_PROMO_EXC  \
# 134  2021-06-02  ...                50.0                            50.00
#
#     PROMO_QTY  PROMO_AMT  SUM_AMT_GAP ITEMGROUP CATEGORY_ID  \
# 134      80.0     454.40       454.40   Spirits        VCS1
#
#                                       PAF_LINK_SUGGEST  \
# 134  https://myprofectus.sharepoint.com/:f:/r/sites...
#
#                                          EMAIL_SUGGEST CLASSIFY_AMOUNT
# 134  https://myprofectus.sharepoint.com/:f:/r/sites...    _LESSTHAN20K
#
# [1 rows x 31 columns]
#     CLASSIFY_CLAIM CLASSIFY_STATE VENDOR_NUMBER      VENDOR_NAME BRANDID  \
# 135            PRO       national         47651  DIAGEO AUST LTD      LL
#
#       ITEMID          ITEMNAME MULTIPLIER_NUM REBATE_ENTITLEMENT_NUM  \
# 135  3041343  TANQUERAY GIN 1L           1.00                   None
#
#       STARTDATE  ... PROMO_PRICE_SUGGEST PRICE_ACTUAL_LESS_THAN_PROMO_EXC  \
# 135  2021-06-02  ...                60.0                            59.99
#
#     PROMO_QTY  PROMO_AMT  SUM_AMT_GAP ITEMGROUP CATEGORY_ID  \
# 135    1766.0    2295.80      2295.80   Spirits        LLS1
#
#                                       PAF_LINK_SUGGEST  \
# 135  Z:\RA\PAF\LL Monthly\01052021-01062021\PAF\Dia...
#
#                                          EMAIL_SUGGEST CLASSIFY_AMOUNT
# 135  Z:\RA\PAF\LL Monthly\01052021-01062021\Email\r...    _LESSTHAN20K
#
# [1 rows x 31 columns]
#     CLASSIFY_CLAIM CLASSIFY_STATE VENDOR_NUMBER      VENDOR_NAME BRANDID  \
# 136            PRO       national         47651  DIAGEO AUST LTD      1C
#
#       ITEMID                                         ITEMNAME MULTIPLIER_NUM  \
# 136  8705178  JOHNNIE WALKER DOUBLE BLACK SCOTCH WHISKY 700ML           1.00
#
#     REBATE_ENTITLEMENT_NUM   STARTDATE  ... PROMO_PRICE_SUGGEST  \
# 136                   8.16  2021-05-27  ...               45.45
#
#     PRICE_ACTUAL_LESS_THAN_PROMO_EXC PROMO_QTY  PROMO_AMT  SUM_AMT_GAP  \
# 136                            45.45     925.0    7548.00      7548.00
#
#     ITEMGROUP CATEGORY_ID                                   PAF_LINK_SUGGEST  \
# 136   Spirits        1CS1  https://myprofectus.sharepoint.com/:f:/r/sites...
#
#                                          EMAIL_SUGGEST CLASSIFY_AMOUNT
# 136  https://myprofectus.sharepoint.com/:f:/r/sites...    _LESSTHAN20K
#
# [1 rows x 31 columns]
#     CLASSIFY_CLAIM CLASSIFY_STATE VENDOR_NUMBER      VENDOR_NAME BRANDID  \
# 137            PRO       national         47651  DIAGEO AUST LTD      1C
#
#       ITEMID                                         ITEMNAME MULTIPLIER_NUM  \
# 137  8705178  JOHNNIE WALKER DOUBLE BLACK SCOTCH WHISKY 700ML           1.00
#
#     REBATE_ENTITLEMENT_NUM   STARTDATE  ... PROMO_PRICE_SUGGEST  \
# 137                   3.73  2021-06-02  ...               45.45
#
#     PRICE_ACTUAL_LESS_THAN_PROMO_EXC PROMO_QTY  PROMO_AMT  SUM_AMT_GAP  \
# 137                            45.45     924.0    7539.84      7539.84
#
#     ITEMGROUP CATEGORY_ID                                   PAF_LINK_SUGGEST  \
# 137   Spirits        1CS1  https://myprofectus.sharepoint.com/:f:/r/sites...
#
#                                          EMAIL_SUGGEST CLASSIFY_AMOUNT
# 137  https://myprofectus.sharepoint.com/:f:/r/sites...    _LESSTHAN20K
#
# [1 rows x 31 columns]
#     CLASSIFY_CLAIM CLASSIFY_STATE VENDOR_NUMBER      VENDOR_NAME BRANDID  \
# 138            PRO       national         47651  DIAGEO AUST LTD      1C
#
#     ITEMID                                         ITEMNAME MULTIPLIER_NUM  \
# 138  78603  DALWHINNIE 15YO SINGLE MALT SCOTCH WHISKY 700ML           1.00
#
#     REBATE_ENTITLEMENT_NUM   STARTDATE  ... PROMO_PRICE_SUGGEST  \
# 138                  10.35  2021-06-04  ...                90.0
#
#     PRICE_ACTUAL_LESS_THAN_PROMO_EXC PROMO_QTY  PROMO_AMT  SUM_AMT_GAP  \
# 138                            88.73      26.0     269.10       269.10
#
#     ITEMGROUP CATEGORY_ID  PAF_LINK_SUGGEST EMAIL_SUGGEST CLASSIFY_AMOUNT
# 138   Spirits        1CS1              None          None    _LESSTHAN20K
#
# [1 rows x 31 columns]
#     CLASSIFY_CLAIM CLASSIFY_STATE VENDOR_NUMBER      VENDOR_NAME BRANDID  \
# 139            PRO       national         47651  DIAGEO AUST LTD      LL
#
#     ITEMID                                        ITEMNAME MULTIPLIER_NUM  \
# 139  78610  LAGAVULIN 16YO SINGLE MALT SCOTCH WHISKY 700ML           1.00
#
#     REBATE_ENTITLEMENT_NUM   STARTDATE  ... PROMO_PRICE_SUGGEST  \
# 139                   None  2021-01-13  ...              104.55
#
#     PRICE_ACTUAL_LESS_THAN_PROMO_EXC PROMO_QTY  PROMO_AMT  SUM_AMT_GAP  \
# 139                            64.53       2.0      19.10        19.10
#
#     ITEMGROUP CATEGORY_ID  PAF_LINK_SUGGEST EMAIL_SUGGEST CLASSIFY_AMOUNT
# 139   Spirits        LLS1              None          None    _LESSTHAN20K
#
# [1 rows x 31 columns]
#     CLASSIFY_CLAIM CLASSIFY_STATE VENDOR_NUMBER      VENDOR_NAME BRANDID  \
# 140            PRO       national         47651  DIAGEO AUST LTD      LL
#
#     ITEMID                                         ITEMNAME MULTIPLIER_NUM  \
# 140  78603  DALWHINNIE 15YO SINGLE MALT SCOTCH WHISKY 700ML           1.00
#
#     REBATE_ENTITLEMENT_NUM   STARTDATE  ... PROMO_PRICE_SUGGEST  \
# 140                   None  2021-06-02  ...               82.73
#
#     PRICE_ACTUAL_LESS_THAN_PROMO_EXC PROMO_QTY  PROMO_AMT  SUM_AMT_GAP  \
# 140                            66.55      92.0     952.20       952.20
#
#     ITEMGROUP CATEGORY_ID  PAF_LINK_SUGGEST EMAIL_SUGGEST CLASSIFY_AMOUNT
# 140   Spirits        LLS1              None          None    _LESSTHAN20K
#
# [1 rows x 31 columns]
#     CLASSIFY_CLAIM CLASSIFY_STATE VENDOR_NUMBER      VENDOR_NAME BRANDID  \
# 141            EVD       national         47651  DIAGEO AUST LTD      VC
#
#      ITEMID                 ITEMNAME MULTIPLIER_NUM REBATE_ENTITLEMENT_NUM  \
# 141  540209  GORDONS DRY GIN 1 LITRE           1.00                   None
#
#       STARTDATE  ... PROMO_PRICE_SUGGEST PRICE_ACTUAL_LESS_THAN_PROMO_EXC  \
# 141  2021-04-28  ...                50.0                            49.96
#
#     PROMO_QTY  PROMO_AMT  SUM_AMT_GAP ITEMGROUP CATEGORY_ID  \
# 141     604.0    3020.00      3020.00   Spirits        VCS1
#
#                                       PAF_LINK_SUGGEST  \
# 141  https://myprofectus.sharepoint.com/:f:/r/sites...
#
#                                          EMAIL_SUGGEST CLASSIFY_AMOUNT
# 141  https://myprofectus.sharepoint.com/:f:/r/sites...    _LESSTHAN20K
#
# [1 rows x 31 columns]
# {'47651_LESSTHAN20K': [['47651', datetime.date(2021, 3, 10), datetime.date(2021, 3, 16), '_LESSTHAN20K', '1C', 2.0], ['47651', datetime.date(2021, 3, 10), datetime.date(2021, 3, 16), '_LESSTHAN20K', 'LL', 2.0], ['47651', datetime.date(2021, 4, 7), datetime.date(2021, 6, 1), '_LESSTHAN20K', '1C', 1.0], ['47651', datetime.date(2021, 4, 28), datetime.date(2021, 6, 1), '_LESSTHAN20K', 'VC', 1.0], ['47651', datetime.date(2021, 5, 5), datetime.date(2021, 6, 1), '_LESSTHAN20K', '1C', 2.0], ['47651', datetime.date(2021, 5, 5), datetime.date(2021, 6, 1), '_LESSTHAN20K', 'LL', 2.0], ['47651', datetime.date(2021, 5, 19), datetime.date(2021, 6, 1), '_LESSTHAN20K', '1C', 2.0], ['47651', datetime.date(2021, 5, 19), datetime.date(2021, 6, 1), '_LESSTHAN20K', 'LL', 2.0], ['47651', datetime.date(2021, 6, 2), datetime.date(2021, 6, 3), '_LESSTHAN20K', '1C', 1.0], ['47651', datetime.date(2021, 6, 2), datetime.date(2021, 6, 7), '_LESSTHAN20K', 'VC', 1.0], ['47651', datetime.date(2021, 6, 2), datetime.date(2021, 6, 10), '_LESSTHAN20K', 'LL', 1.0]]}

# %%
# Out:
# -------------------------------------------------------------------------------------------------------------------------------------
# ['47651', datetime.date(2021, 3, 10), datetime.date(2021, 3, 16), '_LESSTHAN20K', '1C', 2.0]
#   CLASSIFY_CLAIM CLASSIFY_STATE VENDOR_NUMBER      VENDOR_NAME BRANDID  \
# 7            PRO       national         47651  DIAGEO AUST LTD      1C
#
#     ITEMID                 ITEMNAME MULTIPLIER_NUM REBATE_ENTITLEMENT_NUM  \
# 7  3260777  TANQUERAY SEVILLA 700ML           1.00                   None
#
#     STARTDATE  ... ITEMGROUP CATEGORY_ID  \
# 7  2021-03-10  ...   Spirits        1CS1
#
#                                     PAF_LINK_SUGGEST  \
# 7  Z:\RA\PAF\LL Monthly\28022021-01052021\PAF\Dia...
#
#                                        EMAIL_SUGGEST  CLASSIFY_AMOUNT  \
# 7  Z:\RA\PAF\LL Monthly\28022021-01052021\Email\f...     _LESSTHAN20K
#
#                                         CHECK_COLUMN CHECK_BRANDID  \
# 7  PAID PARTITIALY IN CD, CHECK NEWGAP WITH NEWST...         1C,LL
#
#    COUNT_BRANDID FINALSTARTGAP FINALENDGAP
# 7            2.0    2021-03-10  2021-03-16
#
# [1 rows x 36 columns]
# supp_desc DIAGEO AUST LTD
#     ITEMID BRANDID MULTIPLIER_NUM  PROMO_PRICE_SUGGEST SCAN_RATE_SUGGEST
# 0  3260777      1C           1.00                51.82              5.26
# Start product_state_summary
# Done product_state_summary
# Start product_summary
# Done product_summary
# check_list_promo_index
# ['47651', 'DIAGEO AUST LTD', datetime.date(2021, 3, 10), datetime.date(2021, 3, 16), '1C', '1', 'Done']
# -------------------------------------------------------------------------------------------------------------------------------------
# ['47651', datetime.date(2021, 3, 10), datetime.date(2021, 3, 16), '_LESSTHAN20K', 'LL', 2.0]
# Empty DataFrame
# Columns: [CLASSIFY_CLAIM, CLASSIFY_STATE, VENDOR_NUMBER, VENDOR_NAME, BRANDID, ITEMID, ITEMNAME, MULTIPLIER_NUM, REBATE_ENTITLEMENT_NUM, STARTDATE, ENDDATE, PAF_LINK, EMAIL, CLM_QTY, PROMOPRICE_EXC, CLASSIFY_TYPE, ACT_PRICE_EXC, SLS_QTY, NORMAL_PRICE_EXC, ITEMCOGS, SCAN_RATE_SUGGEST, PROMO_PRICE_SUGGEST, PRICE_ACTUAL_LESS_THAN_PROMO_EXC, PROMO_QTY, PROMO_AMT, SUM_AMT_GAP, ITEMGROUP, CATEGORY_ID, PAF_LINK_SUGGEST, EMAIL_SUGGEST, CLASSIFY_AMOUNT, CHECK_COLUMN, CHECK_BRANDID, COUNT_BRANDID, FINALSTARTGAP, FINALENDGAP]
# Index: []
#
# [0 rows x 36 columns]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 17
#      15 print(df_splited_filter)
#      16 supp_num_list_final,item_list_final,item_input_function = get_info(df_splited = df_splited_filter)
# ---> 17 supp_desc = df_splited_filter['VENDOR_NAME'].unique()[0].replace("/","")
#      18 print('supp_desc',supp_desc)
#      19 try:
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
    check_list_promo_index = 1
    for supp_classify_amt,date_list in dict_sup_pro_filter.items():
        index_promo=1
        # summary_index = 1
        summary_index_list = []
        for date in date_list:
            print('-------------------------------------------------------------------------------------------------------------------------------------')
            print(date)
            check_list_promo = []
            if date[5] != 3:
                df_splited_filter = df_raw_filter[(df_raw_filter['VENDOR_NUMBER'] == date[0]) & (df_raw_filter['FINALSTARTGAP'] == date[1])& (df_raw_filter['FINALENDGAP'] == date[2])& (df_raw_filter['CLASSIFY_AMOUNT'] == date[3])& (df_raw_filter['BRANDID'] == date[4]) & (df_raw_filter['COUNT_BRANDID'] == date[5])]
            else:
                df_splited_filter = df_raw_filter[(df_raw_filter['VENDOR_NUMBER'] == date[0]) & (df_raw_filter['FINALSTARTGAP'] == date[1])& (df_raw_filter['FINALENDGAP'] == date[2])& (df_raw_filter['CLASSIFY_AMOUNT'] == date[3])& (df_raw_filter['CHECK_BRANDID'] == date[4]) & (df_raw_filter['COUNT_BRANDID'] == date[5])]
            # get some important variable
            print(df_splited_filter)
            supp_num_list_final,item_list_final,item_input_function = get_info(df_splited = df_splited_filter)
            supp_desc = df_splited_filter['VENDOR_NAME'].unique()[0].replace("/","")
            print('supp_desc',supp_desc)
            try:
                paf_loc = df_splited_filter['PAF_LINK_SUGGEST'].unique()[0]
            except Exception :
                paf_loc = '0'
            try:
                email_loc = df_splited_filter['EMAIL_SUGGEST'].unique()[0]
            except Exception :
                email_loc = '0'
            vendor_num = df_splited_filter['VENDOR_NUMBER'].unique()[0] 
            clm_start = df_splited_filter['FINALSTARTGAP'].unique()[0]
            clm_end = df_splited_filter['FINALENDGAP'].unique()[0]
            #lessthan20k
            amount = date[3]
            # brandid 
            if date[5] == 3 :
                brandid_merged = date[5]
            else:
                brandid_merged = df_splited_filter['BRANDID'].unique()[0]
            # uom
            check_uom = df_splited[['MULTIPLIER_NUM']].drop_duplicates().values.tolist()
            check_uom_final = []
            for uom in check_uom:
                check_uom_final.append(str(int(uom[0])))
            uom = ",".join(check_uom_final)
            #CATEGORY
            if date[5] == 3 :
                category_list = df_splited_filter[['CATEGORY_ID']].drop_duplicates().values.tolist()
                for category_element in category_list:
                    if 'LL' in category_element[0]:
                        category = category_element[0]
                        break
            else:
                category = df_splited_filter['CATEGORY_ID'].unique()[0]
            #create path for excel and path_xlsb for excel
            path_export_final = path_export+'CL_SCAN_'+supp_desc+'_Analyst_date'+amount+'.xlsx'
            path_export_final_xlsb = path_export+'CL_SCAN_'+supp_desc+'_Analyst_date_'+str(vendor_num)+amount+'.xlsb'
            create_worksheet(index_promo=str(index_promo),path_export_final=path_export_final)
            df_splited_filter_2 = df_splited_filter[['ITEMID','BRANDID','MULTIPLIER_NUM','PROMO_PRICE_SUGGEST','SCAN_RATE_SUGGEST']]
            df_splited_filter_2= df_splited_filter_2.drop_duplicates()
            df_splited_filter_2 = df_splited_filter_2.groupby(['ITEMID','BRANDID','MULTIPLIER_NUM']).agg({'PROMO_PRICE_SUGGEST':'max','SCAN_RATE_SUGGEST':'max'}).reset_index()
            print(df_splited_filter_2)

            # print(df_splited_filter_2)
            item_list_dict = df_splited_filter_2.set_index(['ITEMID','BRANDID','MULTIPLIER_NUM'])[['PROMO_PRICE_SUGGEST','SCAN_RATE_SUGGEST']].to_dict('index')
            for key,value in item_list_dict.items():
                item_list_dict[key] = [item_list_dict[key]['PROMO_PRICE_SUGGEST']] + [item_list_dict[key]['SCAN_RATE_SUGGEST']] 
            # To create excel file
            summary_index_list.append(index_promo)
            # df_sales = df_sales_data(cursor = cursor,item_list_dict_gsted = item_list_dict ,start_date = clm_start,end_date = clm_end)
            df_sales,list_data_sales,list_remove_sales = df_sales_data( cursor = cursor, file_sql= file_sql_summ , item_list_dict_gsted =item_list_dict,start_date = clm_start,end_date =clm_end)
            list_data_state,list_remove_state =  product_state_summary(df_sales = df_sales)
            list_data_product ,list_remove_product = product_summary(df_sales = df_sales)
            dict_data_dept = {'df':category,'cell_export':'C4'}
            dict_data_paf_loc = {'df':paf_loc,'cell_export':'R9'}
            dict_data_email_loc = {'df':email_loc,'cell_export':'S9'}
            dict_data_claim_number = {'df':str(index_promo),'cell_export':'B4'}
            list_data = list_data_sales + list_data_state + list_data_product + [dict_data_dept] + [dict_data_paf_loc] + [dict_data_email_loc] + [dict_data_claim_number]
            list_remove = list_remove_sales + list_remove_state + list_remove_product
            #  Fill sheet Complete Daily Sales Data
            writer_excel(data = list_data, remove = list_remove,number_sheet= str(index_promo),path_export_final=path_export_final)  
            index_promo+=1
            check_list_promo_index += 1 
            with xw.App(visible=False) as app:
                print('check_list_promo_index')
                if check_list_promo_index == 2:
                    wb = app.books.open('check_list_promo.xlsx')
                else:
                    wb = app.books.open(path_check_list_promo)
                wb_sheet = wb.sheets['Sheet1']
                check_list_promo = [vendor_num] + [supp_desc]  + [clm_start] + [clm_end]+ [brandid_merged] + [uom] +['Done'] 
                print(check_list_promo)
                wb_sheet.range(f'A{check_list_promo_index}').value =  check_list_promo
                wb.save(path_check_list_promo)
        # Fill sheet Vendor Summary
        fill_summary_sheet(supp_desc = supp_desc,summary_index_list= summary_index_list,path_export_final=path_export_final)         
        remove_sheet_change_xlsb(sheet_name = 'template',path_export_final=path_export_final ,path_export_final_xlsb = path_export_final_xlsb)  
        print('-------------------------------------------------------------------------------------------------------------------------------------')
    print(datetime.datetime.now() - time_start)
# Out:
# -------------------------------------------------------------------------------------------------------------------------------------
# ['47651', datetime.date(2021, 3, 10), datetime.date(2021, 3, 16), '_LESSTHAN20K', '1C', 2.0]
#   CLASSIFY_CLAIM CLASSIFY_STATE VENDOR_NUMBER      VENDOR_NAME BRANDID  \
# 7            PRO       national         47651  DIAGEO AUST LTD      1C
#
#     ITEMID                 ITEMNAME MULTIPLIER_NUM REBATE_ENTITLEMENT_NUM  \
# 7  3260777  TANQUERAY SEVILLA 700ML           1.00                   None
#
#     STARTDATE  ... ITEMGROUP CATEGORY_ID  \
# 7  2021-03-10  ...   Spirits        1CS1
#
#                                     PAF_LINK_SUGGEST  \
# 7  Z:\RA\PAF\LL Monthly\28022021-01052021\PAF\Dia...
#
#                                        EMAIL_SUGGEST  CLASSIFY_AMOUNT  \
# 7  Z:\RA\PAF\LL Monthly\28022021-01052021\Email\f...     _LESSTHAN20K
#
#                                         CHECK_COLUMN CHECK_BRANDID  \
# 7  PAID PARTITIALY IN CD, CHECK NEWGAP WITH NEWST...         1C,LL
#
#    COUNT_BRANDID FINALSTARTGAP FINALENDGAP
# 7            2.0    2021-03-10  2021-03-16
#
# [1 rows x 36 columns]
# supp_desc DIAGEO AUST LTD
#     ITEMID BRANDID MULTIPLIER_NUM  PROMO_PRICE_SUGGEST SCAN_RATE_SUGGEST
# 0  3260777      1C           1.00                51.82              5.26
# Start product_state_summary
# Done product_state_summary
# Start product_summary
# Done product_summary
# check_list_promo_index
# ['47651', 'DIAGEO AUST LTD', datetime.date(2021, 3, 10), datetime.date(2021, 3, 16), '1C', '1', 'Done']
# -------------------------------------------------------------------------------------------------------------------------------------
# ['47651', datetime.date(2021, 3, 10), datetime.date(2021, 3, 16), '_LESSTHAN20K', 'LL', 2.0]
# Empty DataFrame
# Columns: [CLASSIFY_CLAIM, CLASSIFY_STATE, VENDOR_NUMBER, VENDOR_NAME, BRANDID, ITEMID, ITEMNAME, MULTIPLIER_NUM, REBATE_ENTITLEMENT_NUM, STARTDATE, ENDDATE, PAF_LINK, EMAIL, CLM_QTY, PROMOPRICE_EXC, CLASSIFY_TYPE, ACT_PRICE_EXC, SLS_QTY, NORMAL_PRICE_EXC, ITEMCOGS, SCAN_RATE_SUGGEST, PROMO_PRICE_SUGGEST, PRICE_ACTUAL_LESS_THAN_PROMO_EXC, PROMO_QTY, PROMO_AMT, SUM_AMT_GAP, ITEMGROUP, CATEGORY_ID, PAF_LINK_SUGGEST, EMAIL_SUGGEST, CLASSIFY_AMOUNT, CHECK_COLUMN, CHECK_BRANDID, COUNT_BRANDID, FINALSTARTGAP, FINALENDGAP]
# Index: []
#
# [0 rows x 36 columns]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 17
#      15 print(df_splited_filter)
#      16 supp_num_list_final,item_list_final,item_input_function = get_info(df_splited = df_splited_filter)
# ---> 17 supp_desc = df_splited_filter['VENDOR_NAME'].unique()[0].replace("/","")
#      18 print('supp_desc',supp_desc)
#      19 try:
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
import json
import pandas as pd
import snowflake.connector as sf
import os
import xlwings as xw
from xlwings.constants import DeleteShiftDirection
import datetime
import math
import win32com.client as win32
from pywintypes import com_error
pd.options.mode.chained_assignment = None
import logging
import numpy as np

##########################
analyst_name = 'Analyst'
date_batch = 'Date'
#########################
iconPath_email = r"C:\Program Files\Microsoft Office\root\Office16\OUTLOOK.EXE"
iconPath_excel = r"C:\Program Files\Microsoft Office\root\Office16\EXCEL.EXE"

######
os.chdir(r'D:\python\claim_pack_cl')
try:
    os.remove(r'D:\\python\cl_summarizer\claim_pack_cl.log')
except:
    pass

logging.basicConfig(filename="claim_detail.log",
                    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
                    filemode='a')
 
# Creating an object
logger = logging.getLogger()
 
# Setting the threshold of logger to DEBUG
logger.setLevel(logging.INFO)
###########
number_sheet_ap = 'AP'
number_sheet_pd = 'Promo Detail'
number_sheet_cd = 'Claims Detail'

config_coles = r"config.json"

file_sql_claim_pack = r"claim_pack.sql"
file_sql_pd = r"pd.sql"
file_sql_cd = r"cd.sql"
file_sql_ap = r"ap.sql"
file_sql_dept = r"dept.sql"
file_sql_gst = r"gst.sql"
file_sql_summ = r"summarizer.sql"
# file_sql_cd_ref = r"cd_ref.sql"
file_sql_summarizer_state_single = r"summarizer_state_single.sql"
file_sql_summarizer_state_bundle = r"summarizer_state_bundle.sql"
file_sql_summarizer_national_single = r"summarizer_national_single.sql"
file_sql_summarizer_national_bundle = r"summarizer_national_bundle.sql"
file_sql_cd_national = r"cd_national.sql"
file_sql_cd_state = r"cd_state.sql"
file_sql_check_category_name = r"category_name.sql"
file_sql_check_category_id= r"category_id.sql"
file_sql_get_ven_id_name = r"get_ven_id_name.sql"
file_sql_check_prof = r"check_prof.sql"

folder_name = '202111'
###############################################
config_coles = r"config.json"

path_excel = 'CL_SCAN_Vendorname_Analyst_Date.xlsx'
# path_import_item = 'item_import_1.xlsx'
path_vba = 'CL_SCAN_vendorname_analyst_yyyymmdd_LESSTHAN20K.xlsb'

# %%
def set_up(config):
    """Set up connection to SnowFlake"""
    config = json.loads(open(config).read())
    account = config['snowflake']['account']
    user = config['snowflake']['user']
    warehouse = config['snowflake']['warehouse']
    role = config['snowflake']['role']
    database = config['snowflake']['database']
    schema = config['snowflake']['schema']
    password = config['snowflake']['password']
    auth = config['snowflake']['authenticator']

    conn = sf.connect(user=user, password=password, account=account, authenticator=auth,
                      warehouse=warehouse, role=role, database=database, schema=schema)

    cursor = conn.cursor()
    return cursor
cursor = set_up(config = config_coles)
# Out:
# Initiating login request with your identity provider. A browser window should have opened for you to complete the login. If you can't see it, check existing browser windows, or your OS settings. Press CTRL+C to abort and try again...

# %%
class claim_pack_cl:
    def __init__(self,cursor,month_filter):
        self.cursor = cursor
        self.month_filter = month_filter

    def connect_sql(self,file_sql,var_1='',var_2='',var_3='',var_4='',var_5='',var_6='',var_7='',var_8='',var_9=''):
        try:
            self.cursor.execute((open(file_sql).read()).format(var_1,var_2,var_3,var_4,var_5,var_6,var_7,var_8,var_9))
            all_rows = cursor.fetchall()
            field_names = [i[0] for i in cursor.description]
        finally:
            pass
            # conn.close()
        df = pd.DataFrame(all_rows)
        try:
            df.columns = field_names
        except ValueError:
            return pd.DataFrame(columns= field_names)
        return df
    
    def convert_to_input_sql(num_list):
        num_list_final = ''
        # print('SUPP LIST',supp_num_list)
        for num_list in num_list:
            num_list_final = num_list_final + "'" + num_list + "',"
        return num_list_final[:-1]
    
    def check_profectus_claim(self,df):
        list_excel = df.to_dict('records')
        list_prof = []
        for row in list_excel:
            df_check_prof = self.connect_sql(file_sql=file_sql_check_prof,var_1 = row['DEAL'] ,var_2 = row['ITEMIDSKU'],var_3 = row['STARTDATE'],var_4= row['ENDDATE'],var_5 = row['BRANDID'], var_6 = row['UOM'],var_7 = row['STARTDATE'], var_8 =row['ENDDATE'],var_9 = row['STATE'])
            if not df_check_prof.empty: 
                row['ITEM_RAISED'] = df_check_prof['ITEM_RAISED'][0]
                row['CLAIM_PROF'] = df_check_prof['CLAIM_PROF'][0]
                row['FILE_PATH'] = df_check_prof['FILE_PATH'][0]
                list_prof.append(row)
            else:
                list_prof.append(row)
        df_check_prof_detail = pd.DataFrame.from_records(list_prof).reset_index(drop=True)
        return df_check_prof_detail
    
    def create_check_column_for_checklist(self):
        df_raw = self.connect_sql(file_sql=file_sql_claim_pack , var_1= self.month_filter)
        df_raw['KEY'] = df_raw[['REBATEDATE','BRANDID','UOM','STARTDATE','ENDDATE', 'CLASSIFY_STATE','CLASSIFY_PROMO']].astype('str').apply(lambda row: '+'.join(row.values), axis=1)
        df_unique_supp = df_raw[['VENDOR_NUM','KEY']].drop_duplicates().values.tolist()
        dict_ven_promo = {}
        i=0
        for list_sup in df_unique_supp:
            if i == 0:
                dict_ven_promo[list_sup[0]] = [list_sup[1]]
            else:
                if list_sup[0] in dict_ven_promo.keys():
                    dict_ven_promo[list_sup[0]].append(list_sup[1])
                else:
                    dict_ven_promo[list_sup[0]] = [list_sup[1]]
            i+=1
        # Initialize df_raw_check as an empty DataFrame
        if dict_ven_promo == {}:
            df_raw_check = pd.DataFrame(columns= df_raw.columns)
        else:
            j = 0
            for vendor_num,list_key in dict_ven_promo.items():
                # To classify Check_column
                for key in list_key:
                    df_splited = df_raw[(df_raw['VENDOR_NUM'] == vendor_num) & (df_raw['KEY'] == key)] 
                    if df_splited['ELI'].iloc[0] < 100:
                        df_splited['CHECK_COLUMN'] = 'ELI < 100'
                    else:
                        df_check_prof_detail = self.check_profectus_claim(df = df_splited)
                        if 'ITEM_RAISED' in df_check_prof_detail.columns:
                            df_check_prof_detail['CHECK_COLUMN'] = 'PROFECTUS CLAIMED'
                            df_check_prof_detail.loc[(df_check_prof_detail['ITEM_RAISED'].isnull()), 'CHECK_COLUMN'] = 'PROFECTUS_CLAIMED_NOT_RAISED'
                            df_splited = df_check_prof_detail
                        else:
                            classify_state  = df_splited['CLASSIFY_STATE'].iloc[0]
                            classify_promo  = df_splited['CLASSIFY_PROMO'].iloc[0]
                            df_splited['CHECK_COLUMN'] = f'TO QA_{classify_state}_{classify_promo}'
                    print(df_splited)    
                    if j  == 0:
                        df_raw_check = df_splited
                    else:
                        df_raw_check = pd.concat([df_raw_check, df_splited], ignore_index=True)
                    j+=1
        return df_raw_check
    def export(self):
        month_filter_converted = self.month_filter.replace('-','_')
        df_export  = self.create_check_column_for_checklist()
        print(df_export)
        file_name = f'checklist_{month_filter_converted}'
        df_export.to_csv(fr'D:\python\claim_pack_cl\{file_name}.csv',index=False)
        # Load the data from your CSV file
        df_export = pd.read_csv(fr'D:\python\claim_pack_cl\{file_name}.csv')
        # Write the data to an Excel file
        df_export.to_excel(fr'D:\python\claim_pack_cl\{file_name}.xlsx', index=False)
        os.remove(fr'D:\python\claim_pack_cl\{file_name}.csv')
        return df_export

claim_pack_sep = claim_pack_cl(cursor,'2022-09')

# test.cursor

# %%
claim_pack_sep.export()
# Out:
#            REBATEDATE VENDOR_NUM        VENDOR_NAME  \
# 0 2022-07-25 04:35:01     954298  OFF THE VINE (WA)
#
#                                          DESCRIPTION  \
# 0  VC>01.00>National>Wine>PC2>OFF THE VINE (WA)>0...
#
#                                             ITEMNAME ITEMIDSKU  UOM BRANDID  \
# 0  SWINGS & ROUNDABOUTS SEMILLON SAUVIGNON BLANC ...   7442302    1      VC
#
#   CLASSIFY_STATE STATE  ...  \
# 0       NATIONAL    WA  ...
#
#                                                EMAIL CLASSIFY_PROMO  \
# 0  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
#
#   PROMO_INDICATOR_TRANSLATE RRP_FINAL_EXC  CATEGORY_ID ITEMGROUP  ELI_ITEM  \
# 0                         1         18.18         VCW1      Wine       0.0
#
#    ELI                                                KEY CHECK_COLUMN
# 0  0.0  2022-07-25 04:35:01+VC+1+2022-08-03+2022-09-06...    ELI < 100
#
# [1 rows x 29 columns]
#             REBATEDATE VENDOR_NUM                 VENDOR_NAME  \
# 1  2022-08-01 03:37:32     957939  VANGUARD LUXURY BRANDS P/L
# 2  2022-08-01 03:37:32     957939  VANGUARD LUXURY BRANDS P/L
# 3  2022-08-01 03:37:32     957939  VANGUARD LUXURY BRANDS P/L
# 4  2022-08-01 03:37:32     957939  VANGUARD LUXURY BRANDS P/L
# 5  2022-08-01 03:37:32     957939  VANGUARD LUXURY BRANDS P/L
# 6  2022-08-01 03:37:32     957939  VANGUARD LUXURY BRANDS P/L
# 7  2022-08-01 03:37:32     957939  VANGUARD LUXURY BRANDS P/L
# 8  2022-08-01 03:37:32     957939  VANGUARD LUXURY BRANDS P/L
# 9  2022-08-01 03:37:32     957939  VANGUARD LUXURY BRANDS P/L
# 10 2022-08-01 03:37:32     957939  VANGUARD LUXURY BRANDS P/L
# 11 2022-08-01 03:37:32     957939  VANGUARD LUXURY BRANDS P/L
# 12 2022-08-01 03:37:32     957939  VANGUARD LUXURY BRANDS P/L
# 13 2022-08-01 03:37:32     957939  VANGUARD LUXURY BRANDS P/L
# 14 2022-08-01 03:37:32     957939  VANGUARD LUXURY BRANDS P/L
# 15 2022-08-01 03:37:32     957939  VANGUARD LUXURY BRANDS P/L
# 16 2022-08-01 03:37:32     957939  VANGUARD LUXURY BRANDS P/L
# 17 2022-08-01 03:37:32     957939  VANGUARD LUXURY BRANDS P/L
# 18 2022-08-01 03:37:32     957939  VANGUARD LUXURY BRANDS P/L
# 19 2022-08-01 03:37:32     957939  VANGUARD LUXURY BRANDS P/L
# 20 2022-08-01 03:37:32     957939  VANGUARD LUXURY BRANDS P/L
# 21 2022-08-01 03:37:32     957939  VANGUARD LUXURY BRANDS P/L
# 22 2022-08-01 03:37:32     957939  VANGUARD LUXURY BRANDS P/L
# 23 2022-08-01 03:37:32     957939  VANGUARD LUXURY BRANDS P/L
# 24 2022-08-01 03:37:32     957939  VANGUARD LUXURY BRANDS P/L
# 25 2022-08-01 03:37:32     957939  VANGUARD LUXURY BRANDS P/L
# 26 2022-08-01 03:37:32     957939  VANGUARD LUXURY BRANDS P/L
# 27 2022-08-01 03:37:32     957939  VANGUARD LUXURY BRANDS P/L
#
#                                           DESCRIPTION  \
# 1   LL>01.48>National>Spirits>EVERYDAY>VANGUARD LU...
# 2   LL>01.48>National>Spirits>EVERYDAY>VANGUARD LU...
# 3   LL>01.48>National>Spirits>EVERYDAY>VANGUARD LU...
# 4   LL>01.48>National>Spirits>EVERYDAY>VANGUARD LU...
# 5   LL>01.48>National>Spirits>EVERYDAY>VANGUARD LU...
# 6   LL>01.48>National>Spirits>EVERYDAY>VANGUARD LU...
# 7   LL>01.48>National>Spirits>EVERYDAY>VANGUARD LU...
# 8   LL>01.48>National>Spirits>EVERYDAY>VANGUARD LU...
# 9   LL>00.70>National>Spirits>EVERYDAY>VANGUARD LU...
# 10  LL>00.70>National>Spirits>EVERYDAY>VANGUARD LU...
# 11  LL>00.70>National>Spirits>EVERYDAY>VANGUARD LU...
# 12  LL>00.70>National>Spirits>EVERYDAY>VANGUARD LU...
# 13  LL>00.70>National>Spirits>EVERYDAY>VANGUARD LU...
# 14  LL>00.70>National>Spirits>EVERYDAY>VANGUARD LU...
# 15  LL>00.70>National>Spirits>EVERYDAY>VANGUARD LU...
# 16  LL>00.70>National>Spirits>EVERYDAY>VANGUARD LU...
# 17  LL>00.55>National>Spirits>EVERYDAY>VANGUARD LU...
# 18  LL>00.55>National>Spirits>EVERYDAY>VANGUARD LU...
# 19  LL>00.55>National>Spirits>EVERYDAY>VANGUARD LU...
# 20  LL>00.55>National>Spirits>EVERYDAY>VANGUARD LU...
# 21  LL>01.05>National>Spirits>EVERYDAY>VANGUARD LU...
# 22  LL>01.05>National>Spirits>EVERYDAY>VANGUARD LU...
# 23  LL>01.05>National>Spirits>EVERYDAY>VANGUARD LU...
# 24  LL>01.05>National>Spirits>EVERYDAY>VANGUARD LU...
# 25  LL>01.05>National>Spirits>EVERYDAY>VANGUARD LU...
# 26  LL>01.05>National>Spirits>EVERYDAY>VANGUARD LU...
# 27  LL>01.05>National>Spirits>EVERYDAY>VANGUARD LU...
#
#                                 ITEMNAME ITEMIDSKU  UOM BRANDID  \
# 1        FOUR PILLARS RARE DRY GIN 700ML   2146539    1      LL
# 2        FOUR PILLARS RARE DRY GIN 700ML   2146539    1      LL
# 3        FOUR PILLARS RARE DRY GIN 700ML   2146539    1      LL
# 4        FOUR PILLARS RARE DRY GIN 700ML   2146539    1      LL
# 5        FOUR PILLARS RARE DRY GIN 700ML   2146539    1      LL
# 6        FOUR PILLARS RARE DRY GIN 700ML   2146539    1      LL
# 7        FOUR PILLARS RARE DRY GIN 700ML   2146539    1      LL
# 8        FOUR PILLARS RARE DRY GIN 700ML   2146539    1      LL
# 9   FOUR PILLARS BLOODY SHIRAZ GIN 700ML   3022473    1      LL
# 10  FOUR PILLARS BLOODY SHIRAZ GIN 700ML   3022473    1      LL
# 11  FOUR PILLARS BLOODY SHIRAZ GIN 700ML   3022473    1      LL
# 12  FOUR PILLARS BLOODY SHIRAZ GIN 700ML   3022473    1      LL
# 13  FOUR PILLARS BLOODY SHIRAZ GIN 700ML   3022473    1      LL
# 14  FOUR PILLARS BLOODY SHIRAZ GIN 700ML   3022473    1      LL
# 15  FOUR PILLARS BLOODY SHIRAZ GIN 700ML   3022473    1      LL
# 16  FOUR PILLARS BLOODY SHIRAZ GIN 700ML   3022473    1      LL
# 17    THE GOSPEL SOLERA RYE WHISKY 700ML   3710104    1      LL
# 18    THE GOSPEL SOLERA RYE WHISKY 700ML   3710104    1      LL
# 19    THE GOSPEL SOLERA RYE WHISKY 700ML   3710104    1      LL
# 20    THE GOSPEL SOLERA RYE WHISKY 700ML   3710104    1      LL
# 21     FOUR PILLARS OLIVE LEAF GIN 700ML   3883995    1      LL
# 22     FOUR PILLARS OLIVE LEAF GIN 700ML   3883995    1      LL
# 23     FOUR PILLARS OLIVE LEAF GIN 700ML   3883995    1      LL
# 24     FOUR PILLARS OLIVE LEAF GIN 700ML   3883995    1      LL
# 25     FOUR PILLARS OLIVE LEAF GIN 700ML   3883995    1      LL
# 26     FOUR PILLARS OLIVE LEAF GIN 700ML   3883995    1      LL
# 27     FOUR PILLARS OLIVE LEAF GIN 700ML   3883995    1      LL
#
#    CLASSIFY_STATE STATE  ...  \
# 1           STATE   ACT  ...
# 2           STATE   NSW  ...
# 3           STATE    NT  ...
# 4           STATE   QLD  ...
# 5           STATE    SA  ...
# 6           STATE   TAS  ...
# 7           STATE   VIC  ...
# 8           STATE    WA  ...
# 9           STATE   ACT  ...
# 10          STATE   NSW  ...
# 11          STATE    NT  ...
# 12          STATE   QLD  ...
# 13          STATE    SA  ...
# 14          STATE   TAS  ...
# 15          STATE   VIC  ...
# 16          STATE    WA  ...
# 17          STATE   ACT  ...
# 18          STATE   NSW  ...
# 19          STATE   VIC  ...
# 20          STATE    WA  ...
# 21          STATE   ACT  ...
# 22          STATE   NSW  ...
# 23          STATE    NT  ...
# 24          STATE   QLD  ...
# 25          STATE    SA  ...
# 26          STATE   VIC  ...
# 27          STATE    WA  ...
#
#                                                 EMAIL CLASSIFY_PROMO  \
# 1   https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 2   https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 3   https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 4   https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 5   https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 6   https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 7   https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 8   https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 9   https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 10  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 11  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 12  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 13  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 14  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 15  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 16  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 17  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 18  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 19  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 20  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 21  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 22  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 23  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 24  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 25  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 26  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 27  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
#
#    PROMO_INDICATOR_TRANSLATE RRP_FINAL_EXC  CATEGORY_ID ITEMGROUP  ELI_ITEM  \
# 1                          1         70.91         LLS1   Spirits      4.44
# 2                          1         90.00         LLS1   Spirits      4.44
# 3                          1         70.91         LLS1   Spirits      4.44
# 4                          1         90.00         LLS1   Spirits      4.44
# 5                          1         65.45         LLS1   Spirits      4.44
# 6                          1         65.45         LLS1   Spirits      4.44
# 7                          1         90.00         LLS1   Spirits      4.44
# 8                          1         72.73         LLS1   Spirits      4.44
# 9                          1         80.00         LLS1   Spirits      0.70
# 10                         1         90.00         LLS1   Spirits      0.70
# 11                         1         80.00         LLS1   Spirits      0.70
# 12                         1         90.00         LLS1   Spirits      0.70
# 13                         1         80.00         LLS1   Spirits      0.70
# 14                         1         80.00         LLS1   Spirits      0.70
# 15                         1         90.00         LLS1   Spirits      0.70
# 16                         1         81.82         LLS1   Spirits      0.70
# 17                         1         75.45         LLS1   Spirits     -0.55
# 18                         1         76.36         LLS1   Spirits     -0.55
# 19                         1         75.45         LLS1   Spirits     -0.55
# 20                         1         75.45         LLS1   Spirits     -0.55
# 21                         1         60.00         LLS1   Spirits      0.00
# 22                         1         90.00         LLS1   Spirits      0.00
# 23                         1         78.18         LLS1   Spirits      0.00
# 24                         1         78.18         LLS1   Spirits      0.00
# 25                         1         78.18         LLS1   Spirits      0.00
# 26                         1         90.00         LLS1   Spirits      0.00
# 27                         1         80.00         LLS1   Spirits      0.00
#
#      ELI                                                KEY CHECK_COLUMN
# 1   4.59  2022-08-01 03:37:32+LL+1+2022-08-01+2022-09-06...    ELI < 100
# 2   4.59  2022-08-01 03:37:32+LL+1+2022-08-01+2022-09-06...    ELI < 100
# 3   4.59  2022-08-01 03:37:32+LL+1+2022-08-01+2022-09-06...    ELI < 100
# 4   4.59  2022-08-01 03:37:32+LL+1+2022-08-01+2022-09-06...    ELI < 100
# 5   4.59  2022-08-01 03:37:32+LL+1+2022-08-01+2022-09-06...    ELI < 100
# 6   4.59  2022-08-01 03:37:32+LL+1+2022-08-01+2022-09-06...    ELI < 100
# 7   4.59  2022-08-01 03:37:32+LL+1+2022-08-01+2022-09-06...    ELI < 100
# 8   4.59  2022-08-01 03:37:32+LL+1+2022-08-01+2022-09-06...    ELI < 100
# 9   4.59  2022-08-01 03:37:32+LL+1+2022-08-01+2022-09-06...    ELI < 100
# 10  4.59  2022-08-01 03:37:32+LL+1+2022-08-01+2022-09-06...    ELI < 100
# 11  4.59  2022-08-01 03:37:32+LL+1+2022-08-01+2022-09-06...    ELI < 100
# 12  4.59  2022-08-01 03:37:32+LL+1+2022-08-01+2022-09-06...    ELI < 100
# 13  4.59  2022-08-01 03:37:32+LL+1+2022-08-01+2022-09-06...    ELI < 100
# 14  4.59  2022-08-01 03:37:32+LL+1+2022-08-01+2022-09-06...    ELI < 100
# 15  4.59  2022-08-01 03:37:32+LL+1+2022-08-01+2022-09-06...    ELI < 100
# 16  4.59  2022-08-01 03:37:32+LL+1+2022-08-01+2022-09-06...    ELI < 100
# 17  4.59  2022-08-01 03:37:32+LL+1+2022-08-01+2022-09-06...    ELI < 100
# 18  4.59  2022-08-01 03:37:32+LL+1+2022-08-01+2022-09-06...    ELI < 100
# 19  4.59  2022-08-01 03:37:32+LL+1+2022-08-01+2022-09-06...    ELI < 100
# 20  4.59  2022-08-01 03:37:32+LL+1+2022-08-01+2022-09-06...    ELI < 100
# 21  4.59  2022-08-01 03:37:32+LL+1+2022-08-01+2022-09-06...    ELI < 100
# 22  4.59  2022-08-01 03:37:32+LL+1+2022-08-01+2022-09-06...    ELI < 100
# 23  4.59  2022-08-01 03:37:32+LL+1+2022-08-01+2022-09-06...    ELI < 100
# 24  4.59  2022-08-01 03:37:32+LL+1+2022-08-01+2022-09-06...    ELI < 100
# 25  4.59  2022-08-01 03:37:32+LL+1+2022-08-01+2022-09-06...    ELI < 100
# 26  4.59  2022-08-01 03:37:32+LL+1+2022-08-01+2022-09-06...    ELI < 100
# 27  4.59  2022-08-01 03:37:32+LL+1+2022-08-01+2022-09-06...    ELI < 100
#
# [27 rows x 29 columns]
#             REBATEDATE VENDOR_NUM                 VENDOR_NAME  \
# 28 2022-08-01 03:43:34     957939  VANGUARD LUXURY BRANDS P/L
# 29 2022-08-01 03:43:34     957939  VANGUARD LUXURY BRANDS P/L
# 30 2022-08-01 03:43:34     957939  VANGUARD LUXURY BRANDS P/L
# 31 2022-08-01 03:43:34     957939  VANGUARD LUXURY BRANDS P/L
# 32 2022-08-01 03:43:34     957939  VANGUARD LUXURY BRANDS P/L
# 33 2022-08-01 03:43:34     957939  VANGUARD LUXURY BRANDS P/L
#
#                                           DESCRIPTION  \
# 28  1C>00.55>National>Spirits>EVERYDAY>VANGUARD LU...
# 29  1C>00.55>National>Spirits>EVERYDAY>VANGUARD LU...
# 30  1C>00.55>National>Spirits>EVERYDAY>VANGUARD LU...
# 31  1C>00.55>National>Spirits>EVERYDAY>VANGUARD LU...
# 32  1C>00.55>National>Spirits>EVERYDAY>VANGUARD LU...
# 33  1C>00.55>National>Spirits>EVERYDAY>VANGUARD LU...
#
#                               ITEMNAME ITEMIDSKU  UOM BRANDID CLASSIFY_STATE  \
# 28  THE GOSPEL SOLERA RYE WHISKY 700ML   3710104    1      1C       NATIONAL
# 29  THE GOSPEL SOLERA RYE WHISKY 700ML   3710104    1      1C       NATIONAL
# 30  THE GOSPEL SOLERA RYE WHISKY 700ML   3710104    1      1C       NATIONAL
# 31  THE GOSPEL SOLERA RYE WHISKY 700ML   3710104    1      1C       NATIONAL
# 32  THE GOSPEL SOLERA RYE WHISKY 700ML   3710104    1      1C       NATIONAL
# 33  THE GOSPEL SOLERA RYE WHISKY 700ML   3710104    1      1C       NATIONAL
#
#    STATE  ...                                              EMAIL  \
# 28   ACT  ...  https://myprofectus.sharepoint.com/:f:/r/sites...
# 29   NSW  ...  https://myprofectus.sharepoint.com/:f:/r/sites...
# 30   QLD  ...  https://myprofectus.sharepoint.com/:f:/r/sites...
# 31    SA  ...  https://myprofectus.sharepoint.com/:f:/r/sites...
# 32   VIC  ...  https://myprofectus.sharepoint.com/:f:/r/sites...
# 33    WA  ...  https://myprofectus.sharepoint.com/:f:/r/sites...
#
#    CLASSIFY_PROMO PROMO_INDICATOR_TRANSLATE RRP_FINAL_EXC  CATEGORY_ID  \
# 28         SINGLE                         1         73.64         1CS1
# 29         SINGLE                         1         73.64         1CS1
# 30         SINGLE                         1         73.64         1CS1
# 31         SINGLE                         1         73.64         1CS1
# 32         SINGLE                         1         73.64         1CS1
# 33         SINGLE                         1         73.64         1CS1
#
#    ITEMGROUP  ELI_ITEM  ELI  \
# 28   Spirits       0.0  0.0
# 29   Spirits       0.0  0.0
# 30   Spirits       0.0  0.0
# 31   Spirits       0.0  0.0
# 32   Spirits       0.0  0.0
# 33   Spirits       0.0  0.0
#
#                                                   KEY CHECK_COLUMN
# 28  2022-08-01 03:43:34+1C+1+2022-08-01+2022-09-06...    ELI < 100
# 29  2022-08-01 03:43:34+1C+1+2022-08-01+2022-09-06...    ELI < 100
# 30  2022-08-01 03:43:34+1C+1+2022-08-01+2022-09-06...    ELI < 100
# 31  2022-08-01 03:43:34+1C+1+2022-08-01+2022-09-06...    ELI < 100
# 32  2022-08-01 03:43:34+1C+1+2022-08-01+2022-09-06...    ELI < 100
# 33  2022-08-01 03:43:34+1C+1+2022-08-01+2022-09-06...    ELI < 100
#
# [6 rows x 29 columns]
#             REBATEDATE VENDOR_NUM                 VENDOR_NAME  \
# 34 2022-08-01 03:43:34     957939  VANGUARD LUXURY BRANDS P/L
# 35 2022-08-01 03:43:34     957939  VANGUARD LUXURY BRANDS P/L
# 36 2022-08-01 03:43:34     957939  VANGUARD LUXURY BRANDS P/L
# 37 2022-08-01 03:43:34     957939  VANGUARD LUXURY BRANDS P/L
# 38 2022-08-01 03:43:34     957939  VANGUARD LUXURY BRANDS P/L
# 39 2022-08-01 03:43:34     957939  VANGUARD LUXURY BRANDS P/L
# 40 2022-08-01 03:43:34     957939  VANGUARD LUXURY BRANDS P/L
# 41 2022-08-01 03:43:34     957939  VANGUARD LUXURY BRANDS P/L
# 42 2022-08-01 03:43:34     957939  VANGUARD LUXURY BRANDS P/L
# 43 2022-08-01 03:43:34     957939  VANGUARD LUXURY BRANDS P/L
# 44 2022-08-01 03:43:34     957939  VANGUARD LUXURY BRANDS P/L
# 45 2022-08-01 03:43:34     957939  VANGUARD LUXURY BRANDS P/L
# 46 2022-08-01 03:43:34     957939  VANGUARD LUXURY BRANDS P/L
# 47 2022-08-01 03:43:34     957939  VANGUARD LUXURY BRANDS P/L
# 48 2022-08-01 03:43:34     957939  VANGUARD LUXURY BRANDS P/L
# 49 2022-08-01 03:43:34     957939  VANGUARD LUXURY BRANDS P/L
# 50 2022-08-01 03:43:34     957939  VANGUARD LUXURY BRANDS P/L
# 51 2022-08-01 03:43:34     957939  VANGUARD LUXURY BRANDS P/L
#
#                                           DESCRIPTION  \
# 34  1C>01.48>National>Spirits>EVERYDAY>VANGUARD LU...
# 35  1C>01.48>National>Spirits>EVERYDAY>VANGUARD LU...
# 36  1C>01.48>National>Spirits>EVERYDAY>VANGUARD LU...
# 37  1C>01.48>National>Spirits>EVERYDAY>VANGUARD LU...
# 38  1C>01.48>National>Spirits>EVERYDAY>VANGUARD LU...
# 39  1C>01.48>National>Spirits>EVERYDAY>VANGUARD LU...
# 40  1C>00.70>National>Spirits>EVERYDAY>VANGUARD LU...
# 41  1C>00.70>National>Spirits>EVERYDAY>VANGUARD LU...
# 42  1C>00.70>National>Spirits>EVERYDAY>VANGUARD LU...
# 43  1C>00.70>National>Spirits>EVERYDAY>VANGUARD LU...
# 44  1C>00.70>National>Spirits>EVERYDAY>VANGUARD LU...
# 45  1C>00.70>National>Spirits>EVERYDAY>VANGUARD LU...
# 46  1C>01.05>National>Spirits>EVERYDAY>VANGUARD LU...
# 47  1C>01.05>National>Spirits>EVERYDAY>VANGUARD LU...
# 48  1C>01.05>National>Spirits>EVERYDAY>VANGUARD LU...
# 49  1C>01.05>National>Spirits>EVERYDAY>VANGUARD LU...
# 50  1C>01.05>National>Spirits>EVERYDAY>VANGUARD LU...
# 51  1C>01.05>National>Spirits>EVERYDAY>VANGUARD LU...
#
#                                 ITEMNAME ITEMIDSKU  UOM BRANDID  \
# 34       FOUR PILLARS RARE DRY GIN 700ML   2146539    1      1C
# 35       FOUR PILLARS RARE DRY GIN 700ML   2146539    1      1C
# 36       FOUR PILLARS RARE DRY GIN 700ML   2146539    1      1C
# 37       FOUR PILLARS RARE DRY GIN 700ML   2146539    1      1C
# 38       FOUR PILLARS RARE DRY GIN 700ML   2146539    1      1C
# 39       FOUR PILLARS RARE DRY GIN 700ML   2146539    1      1C
# 40  FOUR PILLARS BLOODY SHIRAZ GIN 700ML   3022473    1      1C
# 41  FOUR PILLARS BLOODY SHIRAZ GIN 700ML   3022473    1      1C
# 42  FOUR PILLARS BLOODY SHIRAZ GIN 700ML   3022473    1      1C
# 43  FOUR PILLARS BLOODY SHIRAZ GIN 700ML   3022473    1      1C
# 44  FOUR PILLARS BLOODY SHIRAZ GIN 700ML   3022473    1      1C
# 45  FOUR PILLARS BLOODY SHIRAZ GIN 700ML   3022473    1      1C
# 46     FOUR PILLARS OLIVE LEAF GIN 700ML   3883995    1      1C
# 47     FOUR PILLARS OLIVE LEAF GIN 700ML   3883995    1      1C
# 48     FOUR PILLARS OLIVE LEAF GIN 700ML   3883995    1      1C
# 49     FOUR PILLARS OLIVE LEAF GIN 700ML   3883995    1      1C
# 50     FOUR PILLARS OLIVE LEAF GIN 700ML   3883995    1      1C
# 51     FOUR PILLARS OLIVE LEAF GIN 700ML   3883995    1      1C
#
#    CLASSIFY_STATE STATE  ...  \
# 34          STATE   ACT  ...
# 35          STATE   NSW  ...
# 36          STATE   QLD  ...
# 37          STATE    SA  ...
# 38          STATE   VIC  ...
# 39          STATE    WA  ...
# 40          STATE   ACT  ...
# 41          STATE   NSW  ...
# 42          STATE   QLD  ...
# 43          STATE    SA  ...
# 44          STATE   VIC  ...
# 45          STATE    WA  ...
# 46          STATE   ACT  ...
# 47          STATE   NSW  ...
# 48          STATE   QLD  ...
# 49          STATE    SA  ...
# 50          STATE   VIC  ...
# 51          STATE    WA  ...
#
#                                                 EMAIL CLASSIFY_PROMO  \
# 34  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 35  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 36  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 37  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 38  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 39  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 40  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 41  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 42  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 43  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 44  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 45  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 46  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 47  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 48  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 49  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 50  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 51  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
#
#    PROMO_INDICATOR_TRANSLATE RRP_FINAL_EXC  CATEGORY_ID ITEMGROUP  ELI_ITEM  \
# 34                         1         70.91         1CS1   Spirits      2.96
# 35                         1         70.91         1CS1   Spirits      2.96
# 36                         1         90.00         1CS1   Spirits      2.96
# 37                         1         70.91         1CS1   Spirits      2.96
# 38                         1         90.00         1CS1   Spirits      2.96
# 39                         1         70.91         1CS1   Spirits      2.96
# 40                         1         79.09         1CS1   Spirits      2.80
# 41                         1         90.00         1CS1   Spirits      2.80
# 42                         1         90.00         1CS1   Spirits      2.80
# 43                         1         79.09         1CS1   Spirits      2.80
# 44                         1         90.00         1CS1   Spirits      2.80
# 45                         1         80.00         1CS1   Spirits      2.80
# 46                         1         78.18         1CS1   Spirits      0.00
# 47                         1         78.18         1CS1   Spirits      0.00
# 48                         1         78.18         1CS1   Spirits      0.00
# 49                         1         72.73         1CS1   Spirits      0.00
# 50                         1         90.00         1CS1   Spirits      0.00
# 51                         1         78.18         1CS1   Spirits      0.00
#
#      ELI                                                KEY CHECK_COLUMN
# 34  5.76  2022-08-01 03:43:34+1C+1+2022-08-01+2022-09-06...    ELI < 100
# 35  5.76  2022-08-01 03:43:34+1C+1+2022-08-01+2022-09-06...    ELI < 100
# 36  5.76  2022-08-01 03:43:34+1C+1+2022-08-01+2022-09-06...    ELI < 100
# 37  5.76  2022-08-01 03:43:34+1C+1+2022-08-01+2022-09-06...    ELI < 100
# 38  5.76  2022-08-01 03:43:34+1C+1+2022-08-01+2022-09-06...    ELI < 100
# 39  5.76  2022-08-01 03:43:34+1C+1+2022-08-01+2022-09-06...    ELI < 100
# 40  5.76  2022-08-01 03:43:34+1C+1+2022-08-01+2022-09-06...    ELI < 100
# 41  5.76  2022-08-01 03:43:34+1C+1+2022-08-01+2022-09-06...    ELI < 100
# 42  5.76  2022-08-01 03:43:34+1C+1+2022-08-01+2022-09-06...    ELI < 100
# 43  5.76  2022-08-01 03:43:34+1C+1+2022-08-01+2022-09-06...    ELI < 100
# 44  5.76  2022-08-01 03:43:34+1C+1+2022-08-01+2022-09-06...    ELI < 100
# 45  5.76  2022-08-01 03:43:34+1C+1+2022-08-01+2022-09-06...    ELI < 100
# 46  5.76  2022-08-01 03:43:34+1C+1+2022-08-01+2022-09-06...    ELI < 100
# 47  5.76  2022-08-01 03:43:34+1C+1+2022-08-01+2022-09-06...    ELI < 100
# 48  5.76  2022-08-01 03:43:34+1C+1+2022-08-01+2022-09-06...    ELI < 100
# 49  5.76  2022-08-01 03:43:34+1C+1+2022-08-01+2022-09-06...    ELI < 100
# 50  5.76  2022-08-01 03:43:34+1C+1+2022-08-01+2022-09-06...    ELI < 100
# 51  5.76  2022-08-01 03:43:34+1C+1+2022-08-01+2022-09-06...    ELI < 100
#
# [18 rows x 29 columns]
#             REBATEDATE VENDOR_NUM                 VENDOR_NAME  \
# 52 2022-08-01 03:45:02     957939  VANGUARD LUXURY BRANDS P/L
# 53 2022-08-01 03:45:02     957939  VANGUARD LUXURY BRANDS P/L
# 54 2022-08-01 03:45:02     957939  VANGUARD LUXURY BRANDS P/L
# 55 2022-08-01 03:45:02     957939  VANGUARD LUXURY BRANDS P/L
# 56 2022-08-01 03:45:02     957939  VANGUARD LUXURY BRANDS P/L
# 57 2022-08-01 03:45:02     957939  VANGUARD LUXURY BRANDS P/L
# 58 2022-08-01 03:45:02     957939  VANGUARD LUXURY BRANDS P/L
#
#                                           DESCRIPTION  \
# 52  VC>00.55>National>Spirits>EVERYDAY>VANGUARD LU...
# 53  VC>00.55>National>Spirits>EVERYDAY>VANGUARD LU...
# 54  VC>00.55>National>Spirits>EVERYDAY>VANGUARD LU...
# 55  VC>00.55>National>Spirits>EVERYDAY>VANGUARD LU...
# 56  VC>00.55>National>Spirits>EVERYDAY>VANGUARD LU...
# 57  VC>00.55>National>Spirits>EVERYDAY>VANGUARD LU...
# 58  VC>00.55>National>Spirits>EVERYDAY>VANGUARD LU...
#
#                               ITEMNAME ITEMIDSKU  UOM BRANDID CLASSIFY_STATE  \
# 52  THE GOSPEL SOLERA RYE WHISKY 700ML   3710104    1      VC          STATE
# 53  THE GOSPEL SOLERA RYE WHISKY 700ML   3710104    1      VC          STATE
# 54  THE GOSPEL SOLERA RYE WHISKY 700ML   3710104    1      VC          STATE
# 55  THE GOSPEL SOLERA RYE WHISKY 700ML   3710104    1      VC          STATE
# 56  THE GOSPEL SOLERA RYE WHISKY 700ML   3710104    1      VC          STATE
# 57  THE GOSPEL SOLERA RYE WHISKY 700ML   3710104    1      VC          STATE
# 58  THE GOSPEL SOLERA RYE WHISKY 700ML   3710104    1      VC          STATE
#
#    STATE  ...                                              EMAIL  \
# 52   ACT  ...  https://myprofectus.sharepoint.com/:f:/r/sites...
# 53   NSW  ...  https://myprofectus.sharepoint.com/:f:/r/sites...
# 54    NT  ...  https://myprofectus.sharepoint.com/:f:/r/sites...
# 55   QLD  ...  https://myprofectus.sharepoint.com/:f:/r/sites...
# 56    SA  ...  https://myprofectus.sharepoint.com/:f:/r/sites...
# 57   VIC  ...  https://myprofectus.sharepoint.com/:f:/r/sites...
# 58    WA  ...  https://myprofectus.sharepoint.com/:f:/r/sites...
#
#    CLASSIFY_PROMO PROMO_INDICATOR_TRANSLATE RRP_FINAL_EXC  CATEGORY_ID  \
# 52         SINGLE                         1         65.45         VCS1
# 53         SINGLE                         1         75.45         VCS1
# 54         SINGLE                         1         65.45         VCS1
# 55         SINGLE                         1         65.45         VCS1
# 56         SINGLE                         1         65.45         VCS1
# 57         SINGLE                         1         68.18         VCS1
# 58         SINGLE                         1         68.18         VCS1
#
#    ITEMGROUP  ELI_ITEM  ELI  \
# 52   Spirits       0.0  0.0
# 53   Spirits       0.0  0.0
# 54   Spirits       0.0  0.0
# 55   Spirits       0.0  0.0
# 56   Spirits       0.0  0.0
# 57   Spirits       0.0  0.0
# 58   Spirits       0.0  0.0
#
#                                                   KEY CHECK_COLUMN
# 52  2022-08-01 03:45:02+VC+1+2022-08-01+2022-09-06...    ELI < 100
# 53  2022-08-01 03:45:02+VC+1+2022-08-01+2022-09-06...    ELI < 100
# 54  2022-08-01 03:45:02+VC+1+2022-08-01+2022-09-06...    ELI < 100
# 55  2022-08-01 03:45:02+VC+1+2022-08-01+2022-09-06...    ELI < 100
# 56  2022-08-01 03:45:02+VC+1+2022-08-01+2022-09-06...    ELI < 100
# 57  2022-08-01 03:45:02+VC+1+2022-08-01+2022-09-06...    ELI < 100
# 58  2022-08-01 03:45:02+VC+1+2022-08-01+2022-09-06...    ELI < 100
#
# [7 rows x 29 columns]
#             REBATEDATE VENDOR_NUM                 VENDOR_NAME  \
# 59 2022-08-01 03:45:15     957939  VANGUARD LUXURY BRANDS P/L
# 60 2022-08-01 03:45:15     957939  VANGUARD LUXURY BRANDS P/L
# 61 2022-08-01 03:45:15     957939  VANGUARD LUXURY BRANDS P/L
# 62 2022-08-01 03:45:15     957939  VANGUARD LUXURY BRANDS P/L
# 63 2022-08-01 03:45:15     957939  VANGUARD LUXURY BRANDS P/L
# 64 2022-08-01 03:45:15     957939  VANGUARD LUXURY BRANDS P/L
# 65 2022-08-01 03:45:15     957939  VANGUARD LUXURY BRANDS P/L
# 66 2022-08-01 03:45:15     957939  VANGUARD LUXURY BRANDS P/L
# 67 2022-08-01 03:45:15     957939  VANGUARD LUXURY BRANDS P/L
# 68 2022-08-01 03:45:15     957939  VANGUARD LUXURY BRANDS P/L
# 69 2022-08-01 03:45:15     957939  VANGUARD LUXURY BRANDS P/L
# 70 2022-08-01 03:45:15     957939  VANGUARD LUXURY BRANDS P/L
# 71 2022-08-01 03:45:15     957939  VANGUARD LUXURY BRANDS P/L
# 72 2022-08-01 03:45:15     957939  VANGUARD LUXURY BRANDS P/L
# 73 2022-08-01 03:45:15     957939  VANGUARD LUXURY BRANDS P/L
# 74 2022-08-01 03:45:15     957939  VANGUARD LUXURY BRANDS P/L
# 75 2022-08-01 03:45:15     957939  VANGUARD LUXURY BRANDS P/L
# 76 2022-08-01 03:45:15     957939  VANGUARD LUXURY BRANDS P/L
# 77 2022-08-01 03:45:15     957939  VANGUARD LUXURY BRANDS P/L
# 78 2022-08-01 03:45:15     957939  VANGUARD LUXURY BRANDS P/L
#
#                                           DESCRIPTION  \
# 59  VC>01.48>National>Spirits>EVERYDAY>VANGUARD LU...
# 60  VC>01.48>National>Spirits>EVERYDAY>VANGUARD LU...
# 61  VC>01.48>National>Spirits>EVERYDAY>VANGUARD LU...
# 62  VC>01.48>National>Spirits>EVERYDAY>VANGUARD LU...
# 63  VC>01.48>National>Spirits>EVERYDAY>VANGUARD LU...
# 64  VC>01.48>National>Spirits>EVERYDAY>VANGUARD LU...
# 65  VC>01.48>National>Spirits>EVERYDAY>VANGUARD LU...
# 66  VC>00.30>National>Spirits>EVERYDAY>VANGUARD LU...
# 67  VC>00.30>National>Spirits>EVERYDAY>VANGUARD LU...
# 68  VC>00.30>National>Spirits>EVERYDAY>VANGUARD LU...
# 69  VC>00.30>National>Spirits>EVERYDAY>VANGUARD LU...
# 70  VC>00.30>National>Spirits>EVERYDAY>VANGUARD LU...
# 71  VC>00.30>National>Spirits>EVERYDAY>VANGUARD LU...
# 72  VC>00.30>National>Spirits>EVERYDAY>VANGUARD LU...
# 73  VC>01.05>National>Spirits>EVERYDAY>VANGUARD LU...
# 74  VC>01.05>National>Spirits>EVERYDAY>VANGUARD LU...
# 75  VC>01.05>National>Spirits>EVERYDAY>VANGUARD LU...
# 76  VC>01.05>National>Spirits>EVERYDAY>VANGUARD LU...
# 77  VC>01.05>National>Spirits>EVERYDAY>VANGUARD LU...
# 78  VC>01.05>National>Spirits>EVERYDAY>VANGUARD LU...
#
#                                 ITEMNAME ITEMIDSKU  UOM BRANDID  \
# 59       FOUR PILLARS RARE DRY GIN 700ML   2146539    1      VC
# 60       FOUR PILLARS RARE DRY GIN 700ML   2146539    1      VC
# 61       FOUR PILLARS RARE DRY GIN 700ML   2146539    1      VC
# 62       FOUR PILLARS RARE DRY GIN 700ML   2146539    1      VC
# 63       FOUR PILLARS RARE DRY GIN 700ML   2146539    1      VC
# 64       FOUR PILLARS RARE DRY GIN 700ML   2146539    1      VC
# 65       FOUR PILLARS RARE DRY GIN 700ML   2146539    1      VC
# 66  FOUR PILLARS BLOODY SHIRAZ GIN 700ML   3022473    1      VC
# 67  FOUR PILLARS BLOODY SHIRAZ GIN 700ML   3022473    1      VC
# 68  FOUR PILLARS BLOODY SHIRAZ GIN 700ML   3022473    1      VC
# 69  FOUR PILLARS BLOODY SHIRAZ GIN 700ML   3022473    1      VC
# 70  FOUR PILLARS BLOODY SHIRAZ GIN 700ML   3022473    1      VC
# 71  FOUR PILLARS BLOODY SHIRAZ GIN 700ML   3022473    1      VC
# 72  FOUR PILLARS BLOODY SHIRAZ GIN 700ML   3022473    1      VC
# 73     FOUR PILLARS OLIVE LEAF GIN 700ML   3883995    1      VC
# 74     FOUR PILLARS OLIVE LEAF GIN 700ML   3883995    1      VC
# 75     FOUR PILLARS OLIVE LEAF GIN 700ML   3883995    1      VC
# 76     FOUR PILLARS OLIVE LEAF GIN 700ML   3883995    1      VC
# 77     FOUR PILLARS OLIVE LEAF GIN 700ML   3883995    1      VC
# 78     FOUR PILLARS OLIVE LEAF GIN 700ML   3883995    1      VC
#
#    CLASSIFY_STATE STATE  ...  \
# 59          STATE   ACT  ...
# 60          STATE   NSW  ...
# 61          STATE    NT  ...
# 62          STATE   QLD  ...
# 63          STATE    SA  ...
# 64          STATE   VIC  ...
# 65          STATE    WA  ...
# 66          STATE   ACT  ...
# 67          STATE   NSW  ...
# 68          STATE    NT  ...
# 69          STATE   QLD  ...
# 70          STATE    SA  ...
# 71          STATE   VIC  ...
# 72          STATE    WA  ...
# 73          STATE   ACT  ...
# 74          STATE   NSW  ...
# 75          STATE   QLD  ...
# 76          STATE    SA  ...
# 77          STATE   VIC  ...
# 78          STATE    WA  ...
#
#                                                 EMAIL CLASSIFY_PROMO  \
# 59  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 60  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 61  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 62  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 63  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 64  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 65  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 66  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 67  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 68  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 69  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 70  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 71  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 72  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 73  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 74  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 75  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 76  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 77  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 78  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
#
#    PROMO_INDICATOR_TRANSLATE RRP_FINAL_EXC  CATEGORY_ID ITEMGROUP  ELI_ITEM  \
# 59                         1         65.45         VCS1   Spirits       0.0
# 60                         1         90.00         VCS1   Spirits       0.0
# 61                         1         65.45         VCS1   Spirits       0.0
# 62                         1         90.00         VCS1   Spirits       0.0
# 63                         1         65.45         VCS1   Spirits       0.0
# 64                         1         90.00         VCS1   Spirits       0.0
# 65                         1         65.45         VCS1   Spirits       0.0
# 66                         1         80.91         VCS1   Spirits       0.0
# 67                         1         90.00         VCS1   Spirits       0.0
# 68                         1         80.91         VCS1   Spirits       0.0
# 69                         1         90.00         VCS1   Spirits       0.0
# 70                         1         80.91         VCS1   Spirits       0.0
# 71                         1         90.00         VCS1   Spirits       0.0
# 72                         1         80.91         VCS1   Spirits       0.0
# 73                         1         78.18         VCS1   Spirits       0.0
# 74                         1         78.18         VCS1   Spirits       0.0
# 75                         1         78.18         VCS1   Spirits       0.0
# 76                         1         72.73         VCS1   Spirits       0.0
# 77                         1         90.00         VCS1   Spirits       0.0
# 78                         1         72.73         VCS1   Spirits       0.0
#
#     ELI                                                KEY CHECK_COLUMN
# 59  0.0  2022-08-01 03:45:15+VC+1+2022-08-01+2022-09-06...    ELI < 100
# 60  0.0  2022-08-01 03:45:15+VC+1+2022-08-01+2022-09-06...    ELI < 100
# 61  0.0  2022-08-01 03:45:15+VC+1+2022-08-01+2022-09-06...    ELI < 100
# 62  0.0  2022-08-01 03:45:15+VC+1+2022-08-01+2022-09-06...    ELI < 100
# 63  0.0  2022-08-01 03:45:15+VC+1+2022-08-01+2022-09-06...    ELI < 100
# 64  0.0  2022-08-01 03:45:15+VC+1+2022-08-01+2022-09-06...    ELI < 100
# 65  0.0  2022-08-01 03:45:15+VC+1+2022-08-01+2022-09-06...    ELI < 100
# 66  0.0  2022-08-01 03:45:15+VC+1+2022-08-01+2022-09-06...    ELI < 100
# 67  0.0  2022-08-01 03:45:15+VC+1+2022-08-01+2022-09-06...    ELI < 100
# 68  0.0  2022-08-01 03:45:15+VC+1+2022-08-01+2022-09-06...    ELI < 100
# 69  0.0  2022-08-01 03:45:15+VC+1+2022-08-01+2022-09-06...    ELI < 100
# 70  0.0  2022-08-01 03:45:15+VC+1+2022-08-01+2022-09-06...    ELI < 100
# 71  0.0  2022-08-01 03:45:15+VC+1+2022-08-01+2022-09-06...    ELI < 100
# 72  0.0  2022-08-01 03:45:15+VC+1+2022-08-01+2022-09-06...    ELI < 100
# 73  0.0  2022-08-01 03:45:15+VC+1+2022-08-01+2022-09-06...    ELI < 100
# 74  0.0  2022-08-01 03:45:15+VC+1+2022-08-01+2022-09-06...    ELI < 100
# 75  0.0  2022-08-01 03:45:15+VC+1+2022-08-01+2022-09-06...    ELI < 100
# 76  0.0  2022-08-01 03:45:15+VC+1+2022-08-01+2022-09-06...    ELI < 100
# 77  0.0  2022-08-01 03:45:15+VC+1+2022-08-01+2022-09-06...    ELI < 100
# 78  0.0  2022-08-01 03:45:15+VC+1+2022-08-01+2022-09-06...    ELI < 100
#
# [20 rows x 29 columns]
#             REBATEDATE VENDOR_NUM                 VENDOR_NAME  \
# 79 2022-08-19 04:18:05     957939  VANGUARD LUXURY BRANDS P/L
#
#                                           DESCRIPTION  \
# 79  LL>02.05>National>RTD>VANGUARD LUXURY BRANDS P...
#
#                                        ITEMNAME ITEMIDSKU  UOM BRANDID  \
# 79  FOUR PILLARS RARE DRY GIN & TONIC CAN 250ML   4504414    4      LL
#
#    CLASSIFY_STATE STATE  ...  \
# 79       NATIONAL   VIC  ...
#
#                                                 EMAIL CLASSIFY_PROMO  \
# 79  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
#
#    PROMO_INDICATOR_TRANSLATE RRP_FINAL_EXC  CATEGORY_ID ITEMGROUP  ELI_ITEM  \
# 79                         1         20.00         LLR1       RTD   -248.05
#
#        ELI                                                KEY CHECK_COLUMN
# 79 -248.05  2022-08-19 04:18:05+LL+4+2022-08-24+2022-09-20...    ELI < 100
#
# [1 rows x 29 columns]
#             REBATEDATE VENDOR_NUM                 VENDOR_NAME  \
# 80 2022-08-19 04:36:47     957939  VANGUARD LUXURY BRANDS P/L
# 81 2022-08-19 04:36:47     957939  VANGUARD LUXURY BRANDS P/L
# 82 2022-08-19 04:36:47     957939  VANGUARD LUXURY BRANDS P/L
# 83 2022-08-19 04:36:47     957939  VANGUARD LUXURY BRANDS P/L
# 84 2022-08-19 04:36:47     957939  VANGUARD LUXURY BRANDS P/L
# 85 2022-08-19 04:36:47     957939  VANGUARD LUXURY BRANDS P/L
# 86 2022-08-19 04:36:47     957939  VANGUARD LUXURY BRANDS P/L
# 87 2022-08-19 04:36:47     957939  VANGUARD LUXURY BRANDS P/L
# 88 2022-08-19 04:36:47     957939  VANGUARD LUXURY BRANDS P/L
#
#                                           DESCRIPTION  \
# 80  1C>02.05>National>RTD>VANGUARD LUXURY BRANDS P...
# 81  1C>02.05>National>RTD>VANGUARD LUXURY BRANDS P...
# 82  1C>02.05>National>RTD>VANGUARD LUXURY BRANDS P...
# 83  1C>02.05>National>RTD>VANGUARD LUXURY BRANDS P...
# 84  1C>02.05>National>RTD>VANGUARD LUXURY BRANDS P...
# 85  1C>02.05>National>RTD>VANGUARD LUXURY BRANDS P...
# 86  1C>02.05>National>RTD>VANGUARD LUXURY BRANDS P...
# 87  1C>02.05>National>RTD>VANGUARD LUXURY BRANDS P...
# 88  1C>02.05>National>RTD>VANGUARD LUXURY BRANDS P...
#
#                                             ITEMNAME ITEMIDSKU  UOM BRANDID  \
# 80       FOUR PILLARS RARE DRY GIN & TONIC CAN 250ML   4504414    4      1C
# 81       FOUR PILLARS RARE DRY GIN & TONIC CAN 250ML   4504414    4      1C
# 82       FOUR PILLARS RARE DRY GIN & TONIC CAN 250ML   4504414    4      1C
# 83  FOUR PILLARS BLOODY SHIRAZ GIN & TONIC CAN 250ML   5492730    4      1C
# 84  FOUR PILLARS BLOODY SHIRAZ GIN & TONIC CAN 250ML   5492730    4      1C
# 85  FOUR PILLARS BLOODY SHIRAZ GIN & TONIC CAN 250ML   5492730    4      1C
# 86  FOUR PILLARS BLOODY SHIRAZ GIN & TONIC CAN 250ML   5492730    4      1C
# 87  FOUR PILLARS BLOODY SHIRAZ GIN & TONIC CAN 250ML   5492730    4      1C
# 88  FOUR PILLARS BLOODY SHIRAZ GIN & TONIC CAN 250ML   5492730    4      1C
#
#    CLASSIFY_STATE STATE  ...  \
# 80       NATIONAL   NSW  ...
# 81       NATIONAL   QLD  ...
# 82       NATIONAL   VIC  ...
# 83       NATIONAL   ACT  ...
# 84       NATIONAL   NSW  ...
# 85       NATIONAL   QLD  ...
# 86       NATIONAL    SA  ...
# 87       NATIONAL   VIC  ...
# 88       NATIONAL    WA  ...
#
#                                                 EMAIL CLASSIFY_PROMO  \
# 80  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 81  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 82  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 83  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 84  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 85  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 86  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 87  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 88  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
#
#    PROMO_INDICATOR_TRANSLATE RRP_FINAL_EXC  CATEGORY_ID ITEMGROUP  ELI_ITEM  \
# 80                         1         20.00         1CR1       RTD     -6.15
# 81                         1         20.00         1CR1       RTD     -6.15
# 82                         1         20.00         1CR1       RTD     -6.15
# 83                         1         20.00         1CR1       RTD     -4.10
# 84                         1         20.00         1CR1       RTD     -4.10
# 85                         1         20.00         1CR1       RTD     -4.10
# 86                         1         20.00         1CR1       RTD     -4.10
# 87                         1         20.00         1CR1       RTD     -4.10
# 88                         1         20.00         1CR1       RTD     -4.10
#
#       ELI                                                KEY CHECK_COLUMN
# 80 -10.25  2022-08-19 04:36:47+1C+4+2022-08-24+2022-09-20...    ELI < 100
# 81 -10.25  2022-08-19 04:36:47+1C+4+2022-08-24+2022-09-20...    ELI < 100
# 82 -10.25  2022-08-19 04:36:47+1C+4+2022-08-24+2022-09-20...    ELI < 100
# 83 -10.25  2022-08-19 04:36:47+1C+4+2022-08-24+2022-09-20...    ELI < 100
# 84 -10.25  2022-08-19 04:36:47+1C+4+2022-08-24+2022-09-20...    ELI < 100
# 85 -10.25  2022-08-19 04:36:47+1C+4+2022-08-24+2022-09-20...    ELI < 100
# 86 -10.25  2022-08-19 04:36:47+1C+4+2022-08-24+2022-09-20...    ELI < 100
# 87 -10.25  2022-08-19 04:36:47+1C+4+2022-08-24+2022-09-20...    ELI < 100
# 88 -10.25  2022-08-19 04:36:47+1C+4+2022-08-24+2022-09-20...    ELI < 100
#
# [9 rows x 29 columns]
#             REBATEDATE VENDOR_NUM                 VENDOR_NAME  \
# 89 2022-08-19 04:44:28     957939  VANGUARD LUXURY BRANDS P/L
# 90 2022-08-19 04:44:28     957939  VANGUARD LUXURY BRANDS P/L
# 91 2022-08-19 04:44:28     957939  VANGUARD LUXURY BRANDS P/L
# 92 2022-08-19 04:44:28     957939  VANGUARD LUXURY BRANDS P/L
# 93 2022-08-19 04:44:28     957939  VANGUARD LUXURY BRANDS P/L
# 94 2022-08-19 04:44:28     957939  VANGUARD LUXURY BRANDS P/L
#
#                                           DESCRIPTION  \
# 89  1C>02.05>National>RTD>VANGUARD LUXURY BRANDS P...
# 90  1C>02.05>National>RTD>VANGUARD LUXURY BRANDS P...
# 91  1C>02.05>National>RTD>VANGUARD LUXURY BRANDS P...
# 92  1C>02.05>National>RTD>VANGUARD LUXURY BRANDS P...
# 93  1C>02.05>National>RTD>VANGUARD LUXURY BRANDS P...
# 94  1C>02.05>National>RTD>VANGUARD LUXURY BRANDS P...
#
#                                         ITEMNAME ITEMIDSKU  UOM BRANDID  \
# 89  FOUR PILLARS FRESH YUZU GIN & SODA CAN 250ML   5492762    4      1C
# 90  FOUR PILLARS FRESH YUZU GIN & SODA CAN 250ML   5492762    4      1C
# 91  FOUR PILLARS FRESH YUZU GIN & SODA CAN 250ML   5492762    4      1C
# 92  FOUR PILLARS FRESH YUZU GIN & SODA CAN 250ML   5492762    4      1C
# 93  FOUR PILLARS FRESH YUZU GIN & SODA CAN 250ML   5492762    4      1C
# 94  FOUR PILLARS FRESH YUZU GIN & SODA CAN 250ML   5492762    4      1C
#
#    CLASSIFY_STATE STATE  ...  \
# 89       NATIONAL   ACT  ...
# 90       NATIONAL   NSW  ...
# 91       NATIONAL   QLD  ...
# 92       NATIONAL    SA  ...
# 93       NATIONAL   VIC  ...
# 94       NATIONAL    WA  ...
#
#                                                 EMAIL CLASSIFY_PROMO  \
# 89  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 90  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 91  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 92  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 93  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
# 94  https://myprofectus.sharepoint.com/:f:/r/sites...         SINGLE
#
#    PROMO_INDICATOR_TRANSLATE RRP_FINAL_EXC  CATEGORY_ID ITEMGROUP  ELI_ITEM  \
# 89                         1         20.00         1CR1       RTD      -4.1
# 90                         1         20.00         1CR1       RTD      -4.1
# 91                         1         20.00         1CR1       RTD      -4.1
# 92                         1         20.00         1CR1       RTD      -4.1
# 93                         1         20.00         1CR1       RTD      -4.1
# 94                         1         20.00         1CR1       RTD      -4.1
#
#     ELI                                                KEY CHECK_COLUMN
# 89 -4.1  2022-08-19 04:44:28+1C+4+2022-08-24+2022-09-20...    ELI < 100
# 90 -4.1  2022-08-19 04:44:28+1C+4+2022-08-24+2022-09-20...    ELI < 100
# 91 -4.1  2022-08-19 04:44:28+1C+4+2022-08-24+2022-09-20...    ELI < 100
# 92 -4.1  2022-08-19 04:44:28+1C+4+2022-08-24+2022-09-20...    ELI < 100
# 93 -4.1  2022-08-19 04:44:28+1C+4+2022-08-24+2022-09-20...    ELI < 100
# 94 -4.1  2022-08-19 04:44:28+1C+4+2022-08-24+2022-09-20...    ELI < 100
#
# [6 rows x 29 columns]
#              REBATEDATE VENDOR_NUM                 VENDOR_NAME  \
# 95  2022-08-24 05:08:35     957939  VANGUARD LUXURY BRANDS P/L
# 96  2022-08-24 05:08:35     957939  VANGUARD LUXURY BRANDS P/L
# 97  2022-08-24 05:08:35     957939  VANGUARD LUXURY BRANDS P/L
# 98  2022-08-24 05:08:35     957939  VANGUARD LUXURY BRANDS P/L
# 99  2022-08-24 05:08:35     957939  VANGUARD LUXURY BRANDS P/L
# 100 2022-08-24 05:08:35     957939  VANGUARD LUXURY BRANDS P/L
#
#                                            DESCRIPTION  \
# 95   1C>00.54>National>Spirits>VANGUARD LUXURY BRAN...
# 96   1C>00.54>National>Spirits>VANGUARD LUXURY BRAN...
# 97   1C>00.54>National>Spirits>VANGUARD LUXURY BRAN...
# 98   1C>00.54>National>Spirits>VANGUARD LUXURY BRAN...
# 99   1C>00.54>National>Spirits>VANGUARD LUXURY BRAN...
# 100  1C>00.54>National>Spirits>VANGUARD LUXURY BRAN...
#
#                             ITEMNAME ITEMIDSKU  UOM BRANDID CLASSIFY_STATE  \
# 95   FOUR PILLARS RARE DRY GIN 700ML   2146539    1      1C       NATIONAL
# 96   FOUR PILLARS RARE DRY GIN 700ML   2146539    1      1C       NATIONAL
# ...
# d:\python\claim_pack_cl\claim_pack_cl.ipynb Cell 4 line 7
#      <a href='vscode-notebook-cell:/d%3A/python/claim_pack_cl/claim_pack_cl.ipynb#W3sZmlsZQ%3D%3D?line=67'>68</a>     df_splited['CHECK_COLUMN'] = 'ELI < 100'
#      <a href='vscode-notebook-cell:/d%3A/python/claim_pack_cl/claim_pack_cl.ipynb#W3sZmlsZQ%3D%3D?line=68'>69</a> else:
# ---> <a href='vscode-notebook-cell:/d%3A/python/claim_pack_cl/claim_pack_cl.ipynb#W3sZmlsZQ%3D%3D?line=69'>70</a>     df_check_prof_detail = self.check_profectus_claim(df = df_splited)
#      <a href='vscode-notebook-cell:/d%3A/python/claim_pack_cl/claim_pack_cl.ipynb#W3sZmlsZQ%3D%3D?line=70'>71</a>     if 'ITEM_RAISED' in df_check_prof_detail.columns:
#      <a href='vscode-notebook-cell:/d%3A/python/claim_pack_cl/claim_pack_cl.ipynb#W3sZmlsZQ%3D%3D?line=71'>72</a>         df_check_prof_detail['CHECK_COLUMN'] = 'PROFECTUS CLAIMED'
#
# d:\python\claim_pack_cl\claim_pack_cl.ipynb Cell 4 line 3
#      <a href='vscode-notebook-cell:/d%3A/python/claim_pack_cl/claim_pack_cl.ipynb#W3sZmlsZQ%3D%3D?line=29'>30</a> list_prof = []
#      <a href='vscode-notebook-cell:/d%3A/python/claim_pack_cl/claim_pack_cl.ipynb#W3sZmlsZQ%3D%3D?line=30'>31</a> for row in list_excel:
# ---> <a href='vscode-notebook-cell:/d%3A/python/claim_pack_cl/claim_pack_cl.ipynb#W3sZmlsZQ%3D%3D?line=31'>32</a>     df_check_prof = self.connect_sql(file_sql=file_sql_check_prof,var_1 = row['DEAL'] ,var_2 = row['ITEMIDSKU'],var_3 = row['STARTDATE'],var_4= row['ENDDATE'],var_5 = row['BRANDID'], var_6 = row['UOM'],var_7 = row['STARTDATE'], var_8 =row['ENDDATE'],var_9 = row['STATE'])
#      <a href='vscode-notebook-cell:/d%3A/python/claim_pack_cl/claim_pack_cl.ipynb#W3sZmlsZQ%3D%3D?line=32'>33</a>     if not df_check_prof.empty:
#      <a href='vscode-notebook-cell:/d%3A/python/claim_pack_cl/claim_pack_cl.ipynb#W3sZmlsZQ%3D%3D?line=33'>34</a>         row['ITEM_RAISED'] = df_check_prof['ITEM_RAISED'][0]
#
# d:\python\claim_pack_cl\claim_pack_cl.ipynb Cell 4 line 8
#       <a href='vscode-notebook-cell:/d%3A/python/claim_pack_cl/claim_pack_cl.ipynb#W3sZmlsZQ%3D%3D?line=5'>6</a> def connect_sql(self,file_sql,var_1='',var_2='',var_3='',var_4='',var_5='',var_6='',var_7='',var_8='',var_9=''):
#       <a href='vscode-notebook-cell:/d%3A/python/claim_pack_cl/claim_pack_cl.ipynb#W3sZmlsZQ%3D%3D?line=6'>7</a>     try:
# ----> <a href='vscode-notebook-cell:/d%3A/python/claim_pack_cl/claim_pack_cl.ipynb#W3sZmlsZQ%3D%3D?line=7'>8</a>         self.cursor.execute((open(file_sql).read()).format(var_1,var_2,var_3,var_4,var_5,var_6,var_7,var_8,var_9))
#       <a href='vscode-notebook-cell:/d%3A/python/claim_pack_cl/claim_pack_cl.ipynb#W3sZmlsZQ%3D%3D?line=8'>9</a>         all_rows = cursor.fetchall()
#      <a href='vscode-notebook-cell:/d%3A/python/claim_pack_cl/claim_pack_cl.ipynb#W3sZmlsZQ%3D%3D?line=9'>10</a>         field_names = [i[0] for i in cursor.description]
#
# File d:\python\claim_pack_python\venv\lib\site-packages\snowflake\connector\cursor.py:728, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, file_stream, num_statements)
#     726 if logger.getEffectiveLevel() <= logging.INFO:
#     727     logger.info("query: [%s]", self._format_query_for_log(query))
# --> 728 ret = self._execute_helper(query, **kwargs)
#     729 self._sfqid = (
#     730     ret["data"]["queryId"]
#     731     if "data" in ret and "queryId" in ret["data"]
#     732     else None
#     733 )
#     734 logger.debug(f"sfqid: {self.sfqid}")
#
# File d:\python\claim_pack_python\venv\lib\site-packages\snowflake\connector\cursor.py:511, in SnowflakeCursor._execute_helper(self, query, timeout, statement_params, binding_params, binding_stage, is_internal, describe_only, _no_results, _is_put_get, _no_retry)
#     509 ret = {"data": {}}
#     510 try:
# --> 511     ret = self._connection.cmd_query(
#     512         query,
#     513         self._sequence_counter,
#     514         self._request_id,
#     515         binding_params=binding_params,
#     516         binding_stage=binding_stage,
#     517         is_file_transfer=bool(self._is_file_transfer),
#     518         statement_params=statement_params,
#     519         is_internal=is_internal,
#     520         describe_only=describe_only,
#     521         _no_results=_no_results,
#     522         _no_retry=_no_retry,
#     523     )
#     524 finally:
#     525     try:
#
# File d:\python\claim_pack_python\venv\lib\site-packages\snowflake\connector\connection.py:1043, in SnowflakeConnection.cmd_query(self, sql, sequence_counter, request_id, binding_params, binding_stage, is_file_transfer, statement_params, is_internal, describe_only, _no_results, _update_current_object, _no_retry)
#    1034     logger.debug(
#    1035         "sql=[%s], sequence_id=[%s], is_file_transfer=[%s]",
#    1036         self._format_query_for_log(data["sqlText"]),
#    1037         data["sequenceId"],
#    1038         is_file_transfer,
#    1039     )
#    1041 url_parameters = {REQUEST_ID: request_id}
# -> 1043 ret = self.rest.request(
#    1044     "/queries/v1/query-request?" + urlencode(url_parameters),
#    1045     data,
#    1046     client=client,
#    1047     _no_results=_no_results,
#    1048     _include_retry_params=True,
#    1049     _no_retry=_no_retry,
#    1050 )
#    1052 if ret is None:
#    1053     ret = {"data": {}}
#
# File d:\python\claim_pack_python\venv\lib\site-packages\snowflake\connector\network.py:465, in SnowflakeRestful.request(self, url, body, method, client, _no_results, timeout, _include_retry_params, _no_retry)
#     463     headers[HTTP_HEADER_SERVICE_NAME] = self._connection.service_name
#     464 if method == "post":
# --> 465     return self._post_request(
#     466         url,
#     467         headers,
#     468         json.dumps(body),
#     469         token=self.token,
#     470         _no_results=_no_results,
#     471         timeout=timeout,
#     472         _include_retry_params=_include_retry_params,
#     473         no_retry=_no_retry,
#     474     )
#     475 else:
#     476     return self._get_request(url, headers, token=self.token, timeout=timeout)
#
# File d:\python\claim_pack_python\venv\lib\site-packages\snowflake\connector\network.py:704, in SnowflakeRestful._post_request(self, url, headers, body, token, timeout, _no_results, no_retry, socket_timeout, _include_retry_params)
#     701     ret = probe_connection(full_url)
#     702     pprint(ret)
# --> 704 ret = self.fetch(
#     705     "post",
#     706     full_url,
#     707     headers,
#     708     data=body,
#     709     timeout=timeout,
#     710     token=token,
#     711     no_retry=no_retry,
#     712     socket_timeout=socket_timeout,
#     713     _include_retry_params=_include_retry_params,
#     714 )
#     715 logger.debug(
#     716     "ret[code] = {code}, after post request".format(
#     717         code=(ret.get("code", "N/A"))
#     718     )
#     719 )
#     721 if ret.get("code") == SESSION_EXPIRED_GS_CODE:
#
# File d:\python\claim_pack_python\venv\lib\site-packages\snowflake\connector\network.py:802, in SnowflakeRestful.fetch(self, method, full_url, headers, data, timeout, **kwargs)
#     800 retry_ctx = RetryCtx(timeout, include_retry_params)
#     801 while True:
# --> 802     ret = self._request_exec_wrapper(
#     803         session, method, full_url, headers, data, retry_ctx, **kwargs
#     804     )
#     805     if ret is not None:
#     806         return ret
#
# File d:\python\claim_pack_python\venv\lib\site-packages\snowflake\connector\network.py:845, in SnowflakeRestful._request_exec_wrapper(self, session, method, full_url, headers, data, retry_ctx, no_retry, token, **kwargs)
#     843 full_url = SnowflakeRestful.add_request_guid(full_url)
#     844 try:
# --> 845     return_object = self._request_exec(
#     846         session=session,
#     847         method=method,
#     848         full_url=full_url,
#     849         headers=headers,
#     850         data=data,
#     851         token=token,
#     852         **kwargs,
#     853     )
#     854     if return_object is not None:
#     855         return return_object
#
# File d:\python\claim_pack_python\venv\lib\site-packages\snowflake\connector\network.py:1026, in SnowflakeRestful._request_exec(self, session, method, full_url, headers, data, token, catch_okta_unauthorized_error, is_raw_text, is_raw_binary, binary_data_handler, socket_timeout)
#    1022 download_start_time = get_time_millis()
#    1023 # socket timeout is constant. You should be able to receive
#    1024 # the response within the time. If not, ConnectReadTimeout or
#    1025 # ReadTimeout is raised.
# -> 1026 raw_ret = session.request(
#    1027     method=method,
#    1028     url=full_url,
#    1029     headers=headers,
#    1030     data=input_data,
#    1031     timeout=socket_timeout,
#    1032     verify=True,
#    1033     stream=is_raw_binary,
#    1034     auth=SnowflakeAuth(token),
#    1035 )
#    1036 download_end_time = get_time_millis()
#    1038 try:
#
# File d:\python\claim_pack_python\venv\lib\site-packages\snowflake\connector\vendored\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File d:\python\claim_pack_python\venv\lib\site-packages\snowflake\connector\vendored\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File d:\python\claim_pack_python\venv\lib\site-packages\snowflake\connector\vendored\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File d:\python\claim_pack_python\venv\lib\site-packages\snowflake\connector\vendored\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File d:\python\claim_pack_python\venv\lib\site-packages\snowflake\connector\vendored\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File d:\python\claim_pack_python\venv\lib\site-packages\snowflake\connector\vendored\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File C:\Program Files\Python39\lib\http\client.py:1371, in HTTPConnection.getresponse(self)
#    1369 try:
#    1370     try:
# -> 1371         response.begin()
#    1372     except ConnectionError:
#    1373         self.close()
#
# File C:\Program Files\Python39\lib\http\client.py:319, in HTTPResponse.begin(self)
#     317 # read until we get a non-100 response
#     318 while True:
# --> 319     version, status, reason = self._read_status()
#     320     if status != CONTINUE:
#     321         break
#
# File C:\Program Files\Python39\lib\http\client.py:280, in HTTPResponse._read_status(self)
#     279 def _read_status(self):
# --> 280     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281     if len(line) > _MAXLINE:
#     282         raise LineTooLong("status line")
#
# File C:\Program Files\Python39\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File d:\python\claim_pack_python\venv\lib\site-packages\snowflake\connector\vendored\urllib3\contrib\pyopenssl.py:331, in WrappedSocket.recv_into(self, *args, **kwargs)
#     329         raise
#     330 except OpenSSL.SSL.WantReadError:
# --> 331     if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     332         raise timeout("The read operation timed out")
#     333     else:
#
# File d:\python\claim_pack_python\venv\lib\site-packages\snowflake\connector\vendored\urllib3\util\wait.py:145, in wait_for_read(sock, timeout)
#     141 def wait_for_read(sock, timeout=None):
#     142     """Waits for reading to be available on a given socket.
#     143     Returns True if the socket is readable, or False if the timeout expired.
#     144     """
# --> 145     return wait_for_socket(sock, read=True, timeout=timeout)
#
# File d:\python\claim_pack_python\venv\lib\site-packages\snowflake\connector\vendored\urllib3\util\wait.py:85, in select_wait_for_socket(sock, read, write, timeout)
#      79 # When doing a non-blocking connect, most systems signal success by
#      80 # marking the socket writable. Windows, though, signals success by marked
#      81 # it as "exceptional". We paper over the difference by checking the write
#      82 # sockets for both conditions. (The stdlib selectors module does the same
#      83 # thing.)
#      84 fn = partial(select.select, rcheck, wcheck, wcheck)
# ---> 85 rready, wready, xready = _retry_on_intr(fn, timeout)
#      86 return bool(rready or wready or xready)
#
# File d:\python\claim_pack_python\venv\lib\site-packages\snowflake\connector\vendored\urllib3\util\wait.py:43, in _retry_on_intr(fn, timeout)
#      42 def _retry_on_intr(fn, timeout):
# ---> 43     return fn(timeout)
#
# File d:\python\claim_pack_python\venv\lib\site-packages\snowflake\connector\cursor.py:500, in SnowflakeCursor._execute_helper.<locals>.interrupt_handler(*_)
#     497         except (ValueError, TypeError):
#     498             # ignore failures
#     499             pass
# --> 500 raise KeyboardInterrupt
#
# KeyboardInterrupt:
